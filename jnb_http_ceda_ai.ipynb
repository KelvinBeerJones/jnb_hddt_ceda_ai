# %% [markdown]
# # HDDT Visualisations - AI DNA Graph #

# %% [markdown]
# ## The Anthropological Institute (AI) ##
#
# The database contains the names of 610 members of the AI

# %%
import csv
from operator import itemgetter
import networkx as nx
from networkx.algorithms import community #This part of networkx, for community detection, needs to be imported separately.

# %%
with open('vw_4_ceda_membership_dates_ai.csv', 'r') as nodecsv: # Open the file
    nodereader = csv.reader(nodecsv) # Read the csv
    nodes = [n for n in nodereader][1:]  # Retrieve the data (using Python list comprhension and list slicing to remove the header row.
    
node_names = [n[0] for n in nodes] # Get a list of only the node names    

with open('vw_4_ceda_membership_dates_ai_tuples.csv', 'r') as edgecsv: # Open the file
    edgereader = csv.reader(edgecsv) # Read the csv
    edges = [tuple(e) for e in edgereader][1:]  # Retrieve the data

# %%
nodes
# Out:
# [['H R Adam', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['William (2) Adams', '1,820', '1,900', 'AI', '1858', '1871'],
#  ['Louis Agassiz', '1,807', '1,873', 'AI', '1860', '1871'],
#  ['Alexander Muirhead Aitken', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['William Amhurst Tyssen Amhurst', '1,835', '1,909', 'AI', '1862', '1871'],
#  ['x Antrim', '1,851', '1,918', 'AI', '1871', '1871'],
#  ['William Appleyard', 'NA', 'NA', 'AI', '1854', '1871'],
#  ['William Arbuthnot', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['William Armitage', '1,815', '1,903', 'AI', '1864', '1871'],
#  ['William Armstrong', '1,810', '1,900', 'AI', '1865', '1871'],
#  ['Richard Arnold', '1,808', '1,876', 'AI', '1866', '1871'],
#  ['William Arthur', '1,819', '1,901', 'AI', '1865', '1870'],
#  ['Charles Frederick Ash', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['William Henry Ashurst', '1,819', '1,879', 'AI', '1863', '1871'],
#  ['Charles Atkins', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['George Atkinson', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['Charles Cardale Babington', '1,808', '1,895', 'AI', '1864', '1871'],
#  ['Edward Backhouse', '1,808', '1,879', 'AI', '1870', '1871'],
#  ['Carl Ernst von Baer', '1,792', '1,876', 'AI', '1861', '1871'],
#  ["Walter ('Badgett') Bagehot", '1,826', '1,877', 'AI', '1865', '1871'],
#  ['James Bain', '1,818', '1,898', 'AI', '1865', '1871'],
#  ['John Baker', '1,813', '1,872', 'AI', '1861', '1871'],
#  ['Samuel C Baker', '1,821', '1,893', 'AI', '1866', '1871'],
#  ['William Bailey Baker', '1,828', '1,865', 'AI', '1858', '1871'],
#  ['George Balfour', '1,809', '1,894', 'AI', '1865', '1871'],
#  ['John  Wheeldon Barnes', '1,825', '1,893', 'AI', '1870', '1871'],
#  ['William Roby Barr', '1,832', 'NA', 'AI', '1863', '1871'],
#  ['Thomas Squire Barrett', 'NA', 'NA', 'AI', '1865', '1871'],
#  ['George William Barrington', '1,824', '1,886', 'AI', '1865', '1871'],
#  ['William Edward Bartlett', '1,836', '1,908', 'AI', '1864', '1871'],
#  ['John Stothert Bartrum', '1,817', '1,904', 'AI', '1865', '1871'],
#  ['William Battye', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Hermann Beigel', '1,830', '1,879', 'AI', '1865', '1871'],
#  ['William Abraham Bell', '1,841', '1,921', 'AI', '1869', '1871'],
#  ['Edward Bellamy', '1,837', '1,889', 'AI', '1865', '1871'],
#  ['Henry Walter Bellew', '1,834', '1,892', 'AI', '1870', '1871'],
#  ['Thomas Bendyshe', '1,827', '1,886', 'AI', '1863', '1871'],
#  ['Charles Bennett', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['George Bertram', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['John Bilderbeck', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['James Bischoff', 'NA', 'NA', 'AI', '1865', '1871'],
#  ['Andrew Black', '1,851', '1,916', 'AI', '1870', '1871'],
#  ['William Blackmore', '1,827', '1,878', 'AI', '1866', '1871'],
#  ['Henry Jules Blanc', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['Henry George Bohn', '1,796', '1,884', 'AI', '1861', '1871'],
#  ['William Bollaert', '1,807', '1,876', 'AI', '1862', '1870'],
#  ['Louis Lucien Bonaparte', '1,813', '1,891', 'AI', '1862', '1871'],
#  ['George Bonavia', '1,818', '1,901', 'AI', '1870', '1871'],
#  ['James Bonsor', 'NA', '1,881', 'AI', '1869', '1871'],
#  ['James Bonwick', '1,817', '1,906', 'AI', '1869', '1871'],
#  ['Cunningham Borthwick', '1,813', '1,885', 'AI', '1865', '1871'],
#  ['Sydney Edward Bouverie Bouverie-Pusey',
#   '1,839',
#   '1,911',
#   'AI',
#   '1863',
#   '1871'],
#  ['Jacob Boys', '1,796', '1,884', 'AI', '1863', '1871'],
#  ['Edward William Brabrook', '1,839', '1,930', 'AI', '1864', '1871'],
#  ['Frederick Braby', '1,830', '1,911', 'AI', '1865', '1871'],
#  ['Charles Holt Bracebridge', '1,799', '1,872', 'AI', '1844', '1871'],
#  ['Antonio Brady', '1,811', '1,881', 'AI', '1864', '1871'],
#  ['P A Brady', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['William Bragge', '1,823', '1,884', 'AI', '1870', '1871'],
#  ['A C Brebner', 'NA', '1,873', 'AI', '1867', '1871'],
#  ['James Brebner', '1,793', '1,874', 'AI', '1863', '1871'],
#  ['Charles Brett', 'NA', '1,878', 'AI', '1865', '1871'],
#  ['John Briggs', '1,785', '1,875', 'AI', '1845', '1871'],
#  ['Lindsay Brine', '1,834', '1,906', 'AI', '1869', '1871'],
#  ['Charles Cornish Brown', '1,846', '1,875', 'AI', '1871', '1871'],
#  ['James Roberts Brown', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['John Allen Brown', '1,831', '1,903', 'AI', '1865', '1871'],
#  ['Thomas Henry Browne', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['George Bryant', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['William Bull', '1,828', '1,902', 'AI', '1867', '1871'],
#  ['Luke Burke', 'NA', '1,885', 'AI', '1861', '1864'],
#  ['George Busk', '1,807', '1,886', 'AI', '1863', '1871'],
#  ['William John Busteed', '1,836', '1,914', 'AI', '1867', '1871'],
#  ['Henry Butler', '1,838', 'NA', 'AI', '1864', '1871'],
#  ['James Butler', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Benjamin Bond Cabbell', '1,782', '1,874', 'AI', '1864', '1871'],
#  ['John Calman', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['Archibald Campbell', '1,805', '1,874', 'AI', '1866', '1871'],
#  ['Francis Campbell', '1,798', '1,877', 'AI', '1866', '1871'],
#  ['George (1) Campbell', '1,824', '1,892', 'AI', '1869', '1870'],
#  ['James Campbell', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['T A Campbell', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['Walter Campbell', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['William Camps', 'NA', '1,887', 'AI', '1845', '1871'],
#  ['Charles Napoleon de Cardi', '1,844', '1,906', 'AI', '1868', '1871'],
#  ['William D Carey', '1,837', '1,917', 'AI', '1865', '1871'],
#  ['John Burford Carlill', '1,814', '1,874', 'AI', '1867', '1871'],
#  ['Samuel Cartwright', '1,789', '1,864', 'AI', '1863', '1871'],
#  ['George Catlin', '1,796', '1,872', 'AI', '1866', '1871'],
#  ['John Cavafy', '1,838', '1,901', 'AI', '1865', '1871'],
#  ['John Henry Challis', '1,806', '1,880', 'AI', '1865', '1871'],
#  ['William Chamberlin', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Charles Harcourt Chambers', '1,826', '1,876', 'AI', '1863', '1871'],
#  ['William Chambers', '1,809', '1,882', 'AI', '1864', '1871'],
#  ['Frank Chance', '1,825', '1,897', 'AI', '1863', '1871'],
#  ['Edward Charlesworth', '1,813', '1,893', 'AI', '1866', '1871'],
#  ['William Charlton', '1,814', '1,880', 'AI', '1865', '1871'],
#  ['William Dinsdale Child', 'NA', '1,879', 'AI', '1844', '1871'],
#  ['Samuel Chinnery', '1,828', 'NA', 'AI', '1865', '1871'],
#  ['William Nathan Chipperfield', '1,822', '1,873', 'AI', '1865', '1871'],
#  ['T J Cholmondeley', '1,818', '1,883', 'AI', '1868', '1871'],
#  ['Hyde Clarke', '1,815', '1,895', 'AI', '1864', '1867'],
#  ['Robert Clarke', 'NA', 'NA', 'AI', '1862', '1871'],
#  ['William Aloysius Clavering', '1,800', '1,872', 'AI', '1861', '1871'],
#  ['John (1) Cleghorn', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['H Clerk', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['John Colam', '1,827', '1,910', 'AI', '1870', '1871'],
#  ['Henry Cole', '1,808', '1,882', 'AI', '1864', '1871'],
#  ['Vicat Cole', '1,833', '1,893', 'AI', '1865', '1871'],
#  ['John Sherrard Coleman', '1,828', '1,905', 'AI', '1854', '1871'],
#  ['John Frederick Collingwood', '1,830', '1,923', 'AI', '1863', '1871'],
#  ['W W Collins', 'NA', '1,880', 'AI', '1862', '1871'],
#  ['John (1) Collinson', '1,842', '1,922', 'AI', '1866', '1871'],
#  ['Moncure Daniel Conway', '1,832', '1,907', 'AI', '1869', '1871'],
#  ['William Fothergill Cooke', '1,806', '1,879', 'AI', '1864', '1871'],
#  ['Daniel Cooper', '1,821', '1,902', 'AI', '1863', '1871'],
#  ['Frederick Cooper', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['William C Copperthwaite', '1,809', '1,890', 'AI', '1867', '1871'],
#  ['Tullie Cornthwaite', '1,807', 'NA', 'AI', '1846', '1871'],
#  ['Frederick William Cosens', '1,819', '1,889', 'AI', '1864', '1871'],
#  ['Samuel Courtauld', '1,793', '1,881', 'AI', '1864', '1871'],
#  ['Henry Augustus Cowper', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['Tom junr Craston', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['Oswald John Crawfurd', '1,834', '1,909', 'AI', '1861', '1871'],
#  ['Henry Crowley', 'NA', '1,887', 'AI', '1864', '1871'],
#  ['Moore A Cuffe', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['Richard Cull', 'NA', '1,892', 'AI', '1845', '1857'],
#  ['Richard S Cunliffe', 'NA', '1,879', 'AI', '1855', '1871'],
#  ['Alexander Cunningham', '1,814', '1,893', 'AI', '1869', '1871'],
#  ['Edward Barrett Hodges Curteis', 'NA', '1,886', 'AI', '1867', '1871'],
#  ['John Richmond Cuthbert', 'NA', '1,901', 'AI', '1863', '1871'],
#  ['George Cutler', 'NA', 'NA', 'AI', '1860', '1871'],
#  ["William Barrington D'Almeida", '1,841', '1,897', 'AI', '1867', '1871'],
#  ['x Daa', '1,809', '1,877', 'AI', '1866', '1871'],
#  ['G  Wythes Daniell', 'NA', 'NA', 'AI', '1858', '1871'],
#  ['Robert Dukinfield Darbishire', '1,826', '1,908', 'AI', '1869', '1871'],
#  ['George Russell Dartnell', '1,799', '1,878', 'AI', '1867', '1871'],
#  ['Charles Darwin', '1,809', '1,882', 'AI', '1861', '1871'],
#  ['Arthur Dashwood', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['John Davidson', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Jesse Conway Davies', '1,822', 'NA', 'AI', '1866', '1871'],
#  ['William Davies', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['George Henry Daw', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['William Boyd Dawkins', '1,837', '1,929', 'AI', '1869', '1871'],
#  ['George Dawson', '1,821', '1,876', 'AI', '1863', '1871'],
#  ['x Derby (formerly Stanley)', '1,841', '1,908', 'AI', '1864', '1871'],
#  ['x Devonshire', '1,808', '1,891', 'AI', '1862', '1871'],
#  ['George Dibley', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['Charles Wentworth Dilke', '1,843', '1,911', 'AI', '1870', '1871'],
#  ['John Dingle', '1,812', '1,885', 'AI', '1863', '1871'],
#  ['Jacob Ludwig Dohne', '1,811', '1,879', 'AI', '1856', '1871'],
#  ['John Langdon H Down', '1,828', '1,896', 'AI', '1865', '1871'],
#  ['D I Drakeford', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['John Drummond', '1,793', '1,875', 'AI', '1864', '1871'],
#  ['Alexander Duncan', '1,819', '1,887', 'AI', '1868', '1871'],
#  ['David Duncan', '1,839', '1,923', 'AI', '1870', '1871'],
#  ['Francis Duncan', '1,836', '1,888', 'AI', '1867', '1871'],
#  ['Peter Martin Duncan', '1,824', '1,891', 'AI', '1869', '1869'],
#  ['Alfred John Dunkin', '1,812', '1,879', 'AI', '1868', '1871'],
#  ['Robert Dunn', '1,799', '1,877', 'AI', '1845', '1871'],
#  ['William Eassie', '1,832', '1,888', 'AI', '1864', '1871'],
#  ['Joseph William Eastwood', '1,828', '1,916', 'AI', '1862', '1871'],
#  ['Casper W Eddy', 'NA', 'NA', 'AI', '1868', '1868'],
#  ['John Edwards', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['Walter Elliot', '1,803', '1,887', 'AI', '1869', '1871'],
#  ['C H  Fairfax Ellis', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['William Erle', '1,793', '1,880', 'AI', '1863', '1871'],
#  ['Edward Bickerton Evans', '1,819', '1,893', 'AI', '1864', '1871'],
#  ['John Evans', '1,823', '1,908', 'AI', '1863', '1871'],
#  ['Edward John Eyre', '1,815', '1,901', 'AI', '1864', '1871'],
#  ['William Fairbairn', '1,789', '1,874', 'AI', '1867', '1871'],
#  ['Adam Storey Farrar', '1,826', '1,905', 'AI', '1870', '1871'],
#  ['Frederick Fearon', '1,826', 'NA', 'AI', '1864', '1871'],
#  ['Edwin Foxton Firby', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['Frederick Firebrace', 'NA', '1,917', 'AI', '1864', '1871'],
#  ['James Firm', 'NA', 'NA', 'AI', '1854', '1871'],
#  ['Robert Fischer', 'NA', '1,911', 'AI', '1866', '1871'],
#  ['Morton Coates Fisher', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['George Fleming', '1,833', '1,901', 'AI', '1863', '1871'],
#  ['John Wickham Flower', '1,807', '1,873', 'AI', '1869', '1871'],
#  ['George Folsom', '1,802', '1,869', 'AI', '1866', '1869'],
#  ['David Forbes', '1,828', '1,876', 'AI', '1868', '1871'],
#  ['Robert Nicholas Fowler', '1,828', '1,891', 'AI', '1851', '1871'],
#  ['Charles Henry Fox', 'NA', 'NA', 'AI', '1861', '1871'],
#  ['William Henry Francklyne', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['Augustus Wollaston Franks', '1,826', '1,897', 'AI', '1863', '1871'],
#  ['Thomas Fraser', '1,808', '1,891', 'AI', '1865', '1871'],
#  ['William Freund', '1,806', '1,894', 'AI', '1853', '1871'],
#  ['Danby Palmer Fry', '1,818', '1,903', 'AI', '1863', '1864'],
#  ['A  de Fullner', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['Albert Fytche', '1,820', '1,892', 'AI', '1866', '1871'],
#  ['Douglas Galton', '1,822', '1,899', 'AI', '1861', '1871'],
#  ['Francis Galton', '1,822', '1,911', 'AI', '1862', '1871'],
#  ['C T Gardner', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['Charles Henry Gardner', 'NA', '1,872', 'AI', '1864', '1871'],
#  ['E V Gardner', 'NA', 'NA', 'AI', '1861', '1871'],
#  ['Peter Gardner', 'NA', '1,872', 'AI', '1846', '1871'],
#  ['John Peter Gassiot', '1,797', '1,877', 'AI', '1862', '1871'],
#  ['George Duncan Gibb', '1,821', '1,876', 'AI', '1863', '1871'],
#  ['Enrico Hillyer Giglioli', '1,845', '1,909', 'AI', '1862', '1871'],
#  ['William Gillespie', 'NA', '1,875', 'AI', '1865', '1871'],
#  ['Spyridon Glaucopides', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Augustus Goldsmid', '1,818', '1,874', 'AI', '1865', '1871'],
#  ['Richard Thomas Gore', '1,799', '1,881', 'AI', '1860', '1869'],
#  ['James Gowans', '1,821', '1,890', 'AI', '1866', '1871'],
#  ['Ryves William Graves', 'NA', '1,882', 'AI', '1867', '1871'],
#  ['Frederick King Green', '1,842', '1,915', 'AI', '1869', '1871'],
#  ['George Courthope Green', 'NA', '1,875', 'AI', '1867', '1871'],
#  ['William Greenwell', '1,820', '1,918', 'AI', '1868', '1869'],
#  ['William Rathbone Greg', '1,809', '1,881', 'AI', '1865', '1871'],
#  ['Walter Gregor', '1,825', '1,897', 'AI', '1863', '1871'],
#  ['George Grey', '1,812', '1,898', 'AI', '1860', '1871'],
#  ['Henry Rowland Ellison Grey', '1,834', '1,909', 'AI', '1861', '1871'],
#  ['Lepel Griffin', '1,838', '1,908', 'AI', '1866', '1871'],
#  ['James Oliff Griffits', '1,821', 'NA', 'AI', '1866', '1871'],
#  ['William Vernon Guise', '1,816', '1,887', 'AI', '1869', '1871'],
#  ['James Guthrie', 'NA', '1,900', 'AI', '1862', '1871'],
#  ["Johann Franz ('Julius') Haast", '1,822', '1,887', 'AI', '1870', '1871'],
#  ['Alexander C Hamilton', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['Archibald Hamilton', '1,818', '1,880', 'AI', '1863', '1871'],
#  ['Rowland Hamilton', 'NA', 'NA', 'AI', '1853', '1871'],
#  ['Richard Davis Hanson', '1,805', '1,876', 'AI', '1870', '1871'],
#  ['Clarence Harcourt', 'NA', '1,909', 'AI', '1864', '1871'],
#  ['William Harding', '1,809', '1,890', 'AI', '1865', '1871'],
#  ['Samuel Harraden', 'NA', 'NA', 'AI', '1865', '1871'],
#  ['Arthur B Harris', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['James Penn Harris', '1,817', '1,892', 'AI', '1867', '1871'],
#  ['Charles (1) Harrison', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['William Henry Harrison', '1,840', '1,897', 'AI', '1868', '1871'],
#  ['Alfred Edmund Harriss', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['John E Harvey', 'NA', '1,879', 'AI', '1863', '1871'],
#  ['Frederick Augustus Haserick', '1,828', '1,902', 'AI', '1866', '1871'],
#  ['George Hawkins', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['Ferdinand Vandeveer Hayden', '1,829', '1,887', 'AI', '1869', '1871'],
#  ['Edward Charles Healey', '1,845', '1,906', 'AI', '1864', '1871'],
#  ['Dunbar Isidore Heath', '1,816', '1,888', 'AI', '1864', '1871'],
#  ['G J D Heath', 'NA', '1,880', 'AI', '1869', '1871'],
#  ['Alexander Henderson', '1,804', 'NA', 'AI', '1854', '1871'],
#  ['David Mitchell Henderson', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['P Henderson', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['Joseph Henry', '1,797', '1,878', 'AI', '1869', '1871'],
#  ['Robert Hepburn', 'NA', 'NA', 'AI', '1855', '1871'],
#  ['John Mason Hepworth', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Matthew Heslop', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['B Hewitt', 'NA', 'NA', 'AI', '1871', '1871'],
#  ['Alfred Hewlett', '1,831', '1,918', 'AI', '1863', '1871'],
#  ['James Heywood', '1,810', '1,897', 'AI', '1844', '1871'],
#  ['James Higgin', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Alfred Higgins', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['R  Harvey Hilliard', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['Frederick Hindmarsh', 'NA', '1,875', 'AI', '1845', '1871'],
#  ['W G E Hobbs', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['Brian Houghton Hodgson', '1,801', '1,894', 'AI', '1863', '1871'],
#  ['Kirkman Daniel Hodgson', '1,814', '1,879', 'AI', '1863', '1871'],
#  ['Carl Alphonse Hoffman', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['Joseph Hooker', '1,817', '1,911', 'AI', '1868', '1871'],
#  ['James Hope', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['John Camden Hotten', '1,832', '1,873', 'AI', '1867', '1871'],
#  ['Frederick Hovenden', '1,838', '1,911', 'AI', '1868', '1871'],
#  ['W T Howard', 'NA', 'NA', 'AI', '1865', '1871'],
#  ['Henry Hoyle Howorth', '1,842', '1,923', 'AI', '1856', '1871'],
#  ['Henry Hudson', 'NA', '1,889', 'AI', '1864', '1871'],
#  ['Thomas McKenny Hughes', '1,832', '1,917', 'AI', '1869', '1871'],
#  ['John (2) Hunt', 'NA', '1,879', 'AI', '1866', '1871'],
#  ['William Wilson Hunter', '1,840', '1,900', 'AI', '1870', '1871'],
#  ['Jonathan Hutchinson', '1,828', '1,913', 'AI', '1863', '1871'],
#  ['Thomas Henry Huxley', '1,825', '1,895', 'AI', '1863', '1871'],
#  ['John Inglis', '1,808', '1,891', 'AI', '1854', '1871'],
#  ['x Isenburg', 'NA', 'NA', 'AI', '1854', '1871'],
#  ['Henry (the son) Jackson', '1,839', '1,921', 'AI', '1863', '1871'],
#  ['Henry William (1) Jackson', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['J W Jackson', 'NA', '1,872', 'AI', '1863', '1871'],
#  ['Horatio Gay James', 'NA', 'NA', 'AI', '1865', '1871'],
#  ['John Moore Jeffcott', '1,816', '1,892', 'AI', '1869', '1871'],
#  ['Frederick John Jeffery', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['Edmund Jeffries', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['William Jennings', '1,847', '1,927', 'AI', '1864', '1871'],
#  ['Leonard Jenyns LATER Blomefield', '1,800', '1,893', 'AI', '1863', '1871'],
#  ['William Jepson', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['George Curling Joad', '1,837', '1,881', 'AI', '1865', '1871'],
#  ['Arthur Johnson', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['x Johore', '1,833', '1,895', 'AI', '1866', '1871'],
#  ['James Jones', 'NA', 'NA', 'AI', '1862', '1871'],
#  ['William Arthur Jones', '1,818', '1,873', 'AI', '1869', '1871'],
#  ['J W  (2) Kaye', '1,840', 'NA', 'AI', '1868', '1871'],
#  ['Claude Buchanan Ker', '1,867', '1,925', 'AI', '1867', '1871'],
#  ['Nicolai de Khanikof', '1,819', '1,878', 'AI', '1866', '1871'],
#  ['Joshua Edward Killick', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['William Kincaid', '1,831', '1,909', 'AI', '1865', '1871'],
#  ['Edwin Holborow King', 'NA', '1,900', 'AI', '1869', '1871'],
#  ['Richard King', '1,811', '1,876', 'AI', '1866', '1871'],
#  ['Charles Kingsley', '1,819', '1,875', 'AI', '1856', '1871'],
#  ['David Kinloch', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['Richard Kirwan', '1,828', '1,872', 'AI', '1869', '1871'],
#  ['J L Knapp', 'NA', 'NA', 'AI', '1854', '1871'],
#  ['William White La Barte', '1,824', '1,904', 'AI', '1863', '1870'],
#  ['Samuel Laing', '1,812', '1,897', 'AI', '1864', '1871'],
#  ['Thomas Josiah Laing', '1,810', '1,880', 'AI', '1867', '1871'],
#  ['John Lancaster', '1,815', '1,884', 'AI', '1863', '1871'],
#  ['Augustus Henry Lane Fox later Pitt Rivers',
#   '1,827',
#   '1,900',
#   'AI',
#   '1865',
#   '1871'],
#  ['Andrew Lang', '1,844', '1,912', 'AI', '1861', '1871'],
#  ['J Langlands', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Robert Gordon Latham', '1,812', '1,888', 'AI', '1844', '1853'],
#  ['Edward Lawford', '1,820', '1,899', 'AI', '1867', '1871'],
#  ['Austen Henry Layard', '1,817', '1,894', 'AI', '1853', '1871'],
#  ['John Edward Lee', '1,808', '1,887', 'AI', '1870', '1871'],
#  ['Samuel Lees', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Joseph Leidy', '1,823', '1,891', 'AI', '1869', '1871'],
#  ['Henry Leighton', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Arthur Charles Wriothesley Lennox', '1,842', '1,876', 'AI', '1866', '1871'],
#  ['Richard Lepsius', '1,810', '1,884', 'AI', '1854', '1871'],
#  ['Karl Georg Friedrich Rudolf Leuckart',
#   '1,822',
#   '1,898',
#   'AI',
#   '1861',
#   '1871'],
#  ['William Lockhart', '1,811', '1,896', 'AI', '1861', '1871'],
#  ['Abraham Logan', '1,816', '1,873', 'AI', '1863', '1871'],
#  ['J R Logan', '1,819', '1,869', 'AI', '1866', '1869'],
#  ['William Long', '1,817', '1,886', 'AI', '1869', '1871'],
#  ['Edward Lord', '1,812', '1,875', 'AI', '1863', '1871'],
#  ['Horatio Love', 'NA', '1,882', 'AI', '1850', '1871'],
#  ['Basil Lovery', 'NA', '1,897', 'AI', '1868', '1871'],
#  ['John Lubbock', '1,834', '1,913', 'AI', '1863', '1871'],
#  ['Johann Constantin August Lucae', '1,835', '1,911', 'AI', '1861', '1871'],
#  ['William Collings Lukis', '1,817', '1,892', 'AI', '1864', '1871'],
#  ['John Alfred Lush', '1,815', '1,888', 'AI', '1869', '1871'],
#  ['Coryndon H Luxmoore', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['John Macartney', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['John Gray Macfarlane', 'NA', 'NA', 'AI', '1865', '1871'],
#  ['G Macgowan', 'NA', 'NA', 'AI', '1861', '1871'],
#  ['Draper Mackinder', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['David Mackintosh', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Hector Maclean', '1,818', '1,893', 'AI', '1867', '1871'],
#  ['George Macleay', '1,809', '1,891', 'AI', '1869', '1869'],
#  ['Andrew Maclure', '1,813', '1,886', 'AI', '1867', '1871'],
#  ['William Elphinstone Malcolm', '1,817', '1,907', 'AI', '1855', '1871'],
#  ['Robert James Mann', '1,817', '1,886', 'AI', '1866', '1871'],
#  ['Clements Robert Markham', '1,830', '1,916', 'AI', '1864', '1871'],
#  ['Matthew Henry Marsh', '1,810', '1,881', 'AI', '1862', '1871'],
#  ['Edward W Martin', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['John (2) Martin', '1,812', '1,874', 'AI', '1864', '1871'],
#  ['Richard Biddulph Martin', '1,838', '1,916', 'AI', '1868', '1871'],
#  ['James Wood Mason', '1,846', '1,893', 'AI', '1869', '1871'],
#  ['James Mathieson', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Henry Matthews', '1,826', '1,913', 'AI', '1863', '1871'],
#  ['Alfred Maury', '1,817', '1,892', 'AI', '1861', '1871'],
#  ['Peter Benson Maxwell', '1,817', '1,893', 'AI', '1867', '1871'],
#  ['Edward Hooper May', '1,831', '1,914', 'AI', '1867', '1871'],
#  ['Joseph Mayer', '1,803', '1,886', 'AI', '1854', '1871'],
#  ['William Frederick Mayers', '1,831', '1,878', 'AI', '1864', '1871'],
#  ['John S Mayson', '1,825', 'NA', 'AI', '1856', '1864'],
#  ['James McClelland', '1,799', '1,879', 'AI', '1854', '1870'],
#  ['John McCormick', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['John McDonnell', '1,839', '1,879', 'AI', '1864', '1871'],
#  ['John Ferguson McLennan', '1,827', '1,881', 'AI', '1870', '1871'],
#  ['Walter McLeod', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['John Frederick McNair', '1,828', '1,910', 'AI', '1866', '1871'],
#  ['Barr Meadows', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Charles William Carter Madden Medlicott',
#   '1,839',
#   'NA',
#   'AI',
#   '1867',
#   '1871'],
#  ['James Aitken Meigs', '1,829', '1,879', 'AI', '1861', '1871'],
#  ['John Magens Mello', '1,836', '1,903', 'AI', '1867', '1871'],
#  ['Evan Powell Meredith', '1,811', '1,889', 'AI', '1867', '1871'],
#  ['Alexander Michie', '1,833', '1,902', 'AI', '1863', '1871'],
#  ['William Augustus Miles', 'NA', 'NA', 'AI', '1851', '1871'],
#  ['John Miller', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Joseph Milligan', '1,807', '1,884', 'AI', '1863', '1871'],
#  ['Henry F Mills', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['Henri Milne-Edwards', '1,800', '1,885', 'AI', '1863', '1871'],
#  ['x Milton', '1,839', '1,877', 'AI', '1864', '1871'],
#  ['Albert Mitchell', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['Alexander (1) Mitchell', '1,831', '1,873', 'AI', '1858', '1871'],
#  ['Matthew Moggridge', '1,803', '1,882', 'AI', '1869', '1871'],
#  ['Frederick Butler Montgomerie', '1,833', 'NA', 'AI', '1864', '1871'],
#  ['John Moody', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['George Moore', '1,803', '1,880', 'AI', '1864', '1871'],
#  ['Henry Reginald Moore', 'NA', 'NA', 'AI', '1865', '1871'],
#  ['John (1) Moore', 'NA', '1,882', 'AI', '1864', '1871'],
#  ['John (2) Moore', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['Robert Waters Moore', '1,819', '1,884', 'AI', '1866', '1871'],
#  ['Fortescue John Morgan', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['William Henry Morgan', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['James Cotter Morison', '1,832', '1,888', 'AI', '1863', '1871'],
#  ['Edward Rowley Morris', '1,828', '1,893', 'AI', '1871', '1871'],
#  ['Eugene Morris', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['John Morris', '1,823', '1,905', 'AI', '1869', '1871'],
#  ['James Holmes Morrison', '1,842', '1,917', 'AI', '1869', '1871'],
#  ['Walter Morrison', '1,836', '1,921', 'AI', '1870', '1871'],
#  ['John Mortimer', 'NA', '1,871', 'AI', '1864', '1871'],
#  ['John Robert Mortimer', '1,825', '1,911', 'AI', '1870', '1871'],
#  ['Henry Muirhead', '1,814', '1,890', 'AI', '1867', '1871'],
#  ['Friedrich Max Muller', '1,823', '1,900', 'AI', '1865', '1871'],
#  ['Francis Kerridge Munton', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['J C Murray', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Charles Ottley Groom Napier', '1,839', '1,894', 'AI', '1865', '1871'],
#  ['William Napier', '1,804', '1,879', 'AI', '1868', '1871'],
#  ['Davyd William Nash', '1,810', '1,876', 'AI', '1848', '1871'],
#  ['Samuel Nash', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['J  Dormer Neale', 'NA', '1,884', 'AI', '1868', '1871'],
#  ['Robert Stirling (1) Newall', '1,812', '1,889', 'AI', '1870', '1871'],
#  ['P H Newnham', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Alfred Vincent Newton', 'NA', 'NA', 'AI', '1865', '1871'],
#  ['Thomas Nicholas', 'NA', 'NA', 'AI', '1869', '1869'],
#  ['Brinsley Nicholson', '1,824', '1,892', 'AI', '1855', '1871'],
#  ['Charles Nicholson', '1,808', '1,903', 'AI', '1858', '1865'],
#  ['Giustiniano Nicolucci', '1,819', '1,904', 'AI', '1862', '1871'],
#  ['Sven Nilsson', '1,787', '1,883', 'AI', '1860', '1871'],
#  ['Karl Friedrich Nordmann', '1,830', 'NA', 'AI', '1868', '1871'],
#  ['Henry Norsworthy', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Samuel William North', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Josiah Clark Nott', '1,804', '1,873', 'AI', '1861', '1871'],
#  ['John Nottingham', '1,810', '1,895', 'AI', '1867', '1871'],
#  ['Richard Maddock Nunn', 'NA', '1,876', 'AI', '1865', '1871'],
#  ["P O'Callaghan", 'NA', 'NA', 'AI', '1870', '1871'],
#  ["Luke Smyth O'Connor", '1,806', '1,873', 'AI', '1864', '1871'],
#  ["Edward O'Riley", 'NA', 'NA', 'AI', '1860', '1871'],
#  ['Samuel Pasfield Oliver', '1,838', '1,907', 'AI', '1868', '1869'],
#  ['Gustav Oppert', '1,836', '1,908', 'AI', '1869', '1871'],
#  ['John Benn Ormathwaite', '1,798', '1,881', 'AI', '1864', '1871'],
#  ['W  Billing Orton', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['Sherard Osborn', '1,822', '1,875', 'AI', '1867', '1871'],
#  ['John William Willoughby Osborne', '1,833', '1,881', 'AI', '1864', '1871'],
#  ['Charles Otto', '1,795', '1,879', 'AI', '1853', '1871'],
#  ['Frederick Ouvry', '1,814', '1,881', 'AI', '1869', '1871'],
#  ['John Fletcher Owen', '1,839', '1,924', 'AI', '1868', '1871'],
#  ['Richard Owen', '1,804', '1,892', 'AI', '1863', '1871'],
#  ['Robert Brisco Owen', '1,799', '1,883', 'AI', '1863', '1871'],
#  ['Samuel R J Owen', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['William Gifford Palgrave', '1,826', '1,888', 'AI', '1868', '1871'],
#  ['Walter Mantell Parker', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['J  Charlton Parr', 'NA', 'NA', 'AI', '1868', '1871'],
#  ["Theodore D'Orville Partridge", 'NA', '1,897', 'AI', '1867', '1871'],
#  ['Edmund Patterson', 'NA', 'NA', 'AI', '1860', '1871'],
#  ['R W Payne', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['Thomas Bevill Peacock', '1,812', '1,882', 'AI', '1863', '1871'],
#  ['Alfred Henry Pechell', '1,827', '1,885', 'AI', '1866', '1871'],
#  ['Robert Peel', '1,838', '1,894', 'AI', '1866', '1871'],
#  ['John Peiser', '1,801', '1,886', 'AI', '1863', '1871'],
#  ['William Peppe', 'NA', '1,937', 'AI', '1869', '1871'],
#  ['Josef Anton Maximilian Perty', '1,804', '1,884', 'AI', '1860', '1871'],
#  ['Horace William Petherick', '1,839', '1,919', 'AI', '1863', '1871'],
#  ['Arthur Phayre', '1,812', '1,885', 'AI', '1862', '1871'],
#  ['Philip Phoebus', '1,804', '1,880', 'AI', '1861', '1867'],
#  ['Charles Pickering', '1,805', '1,878', 'AI', '1861', '1871'],
#  ['Francois Jules Pictet', '1,809', '1,872', 'AI', '1860', '1871'],
#  ['Bedford Pim', '1,826', '1,886', 'AI', '1866', '1871'],
#  ['John Platts', '1,830', '1,904', 'AI', '1869', '1871'],
#  ['Matthew Conway Poole', '1,841', '1,885', 'AI', '1871', '1871'],
#  ['Joseph Legg Postlethwaite', 'NA', '1,871', 'AI', '1844', '1871'],
#  ['Joseph Prestwich', '1,812', '1,896', 'AI', '1869', '1871'],
#  ['Frederick George Hilton Price', '1,842', '1,909', 'AI', '1868', '1871'],
#  ['Lorenzo T C Price', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['Thomas Prichard', 'NA', '1,878', 'AI', '1865', '1871'],
#  ['Henry jun Prigg', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Alfred Pulford', '1,823', '1,896', 'AI', '1866', '1871'],
#  ['Arthur Giles Puller', '1,833', '1,885', 'AI', '1865', '1871'],
#  ['Bernard Quaritch', '1,819', '1,899', 'AI', '1865', '1871'],
#  ['Lambert Adolphe Jacques Quetelet', '1,796', '1,874', 'AI', '1853', '1871'],
#  ['James Rae', 'NA', '1,891', 'AI', '1864', '1871'],
#  ['A , jun Ramsay', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['John Ramsay', '1,814', '1,892', 'AI', '1867', '1871'],
#  ['William Francis Ramsay', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Jabez Spence Ramskill', '1,825', '1,897', 'AI', '1865', '1871'],
#  ['Edwin Ransom', '1,841', '1,927', 'AI', '1868', '1871'],
#  ['Goday Naraen Gajapati Rao', '1,828', '1,903', 'AI', '1866', '1871'],
#  ['Charles Ratcliff', '1,815', '1,885', 'AI', '1863', '1871'],
#  ['Henry Rawlinson', '1,810', '1,895', 'AI', '1853', '1871'],
#  ['Lestock Robert Reid', 'NA', '1,879', 'AI', '1861', '1871'],
#  ['Ernest Renan', '1,823', '1,892', 'AI', '1861', '1871'],
#  ['Charles Jeremiah Renshaw', '1,841', '1,916', 'AI', '1863', '1871'],
#  ['Edward Jackson Riccard', 'NA', '1,872', 'AI', '1867', '1871'],
#  ['Franklin Thomas Richards', '1,847', '1,905', 'AI', '1867', '1871'],
#  ['Charles Richardson', '1,814', '1,896', 'AI', '1864', '1871'],
#  ['Francis Richardson', '1,815', '1,896', 'AI', '1863', '1871'],
#  ['George Thorne Ricketts', '1,826', '1,919', 'AI', '1870', '1871'],
#  ['x Ripon, De Grey and', '1,827', '1,909', 'AI', '1850', '1871'],
#  ['John Henry Rivett-Carnac', '1,839', '1,923', 'AI', '1870', '1871'],
#  ['Charles Robert des Ruffieres', 'NA', '1,883', 'AI', '1863', '1871'],
#  ['Daniel Brooke Robertson', '1,810', '1,881', 'AI', '1864', '1871'],
#  ['Edward Robinson', '1,794', '1,863', 'AI', '1852', '1863'],
#  ['William Robinson', 'NA', '1,880', 'AI', '1865', '1871'],
#  ['Sampson Roch', '1,829', '1,906', 'AI', '1865', '1871'],
#  ['George Rogers', '1,809', '1,891', 'AI', '1867', '1871'],
#  ['George Rolleston', '1,829', '1,881', 'AI', '1860', '1871'],
#  ['Hyacinthe Ronay', '1,814', '1,889', 'AI', '1865', '1871'],
#  ['Charles Rooke', '1,809', '1,872', 'AI', '1866', '1869'],
#  ['James Anderson Rose', '1,819', '1,890', 'AI', '1868', '1871'],
#  ['x Rosehill', '1,843', '1,891', 'AI', '1870', '1871'],
#  ['John George Clunies Ross', '1,823', '1,871', 'AI', '1860', '1871'],
#  ['Ankithum Venkata Nursing Row', '1,827', '1,892', 'AI', '1870', '1871'],
#  ['Harry Crommelin Rowcroft', '1,840', '1,876', 'AI', '1861', '1871'],
#  ['Frederick William Rudler', '1,840', '1,915', 'AI', '1871', '1871'],
#  ['H  Hodgson Rugg', '1,812', '1,891', 'AI', '1867', '1871'],
#  ['John Ruskin', '1,819', '1,900', 'AI', '1864', '1871'],
#  ['A H Russell', '1,837', '1,916', 'AI', '1860', '1871'],
#  ['Charles E Russell', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['Edward Ryan', '1,793', '1,875', 'AI', '1862', '1871'],
#  ['Oluf Rygh', '1,833', '1,899', 'AI', '1866', '1871'],
#  ['David Salomons', '1,797', '1,873', 'AI', '1860', '1871'],
#  ['William Severin Salting', '1,837', '1,905', 'AI', '1863', '1871'],
#  ['Alfred Sanders', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['W  Walbank Sanderson', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['W H Scattergood', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['William Mason Scharlieb', '1,829', '1,891', 'AI', '1867', '1871'],
#  ['Carl Ritter von Scherzer', '1,821', '1,903', 'AI', '1861', '1871'],
#  ['E Schiemann', 'NA', 'NA', 'AI', '1870', '1871'],
#  ['John (2) Scott', '1,817', '1,890', 'AI', '1867', '1871'],
#  ['Robert S Scott', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Thomas Scott', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['John Scouler', '1,804', '1,871', 'AI', '1855', '1871'],
#  ['Lucy Ellen Sewall', '1,837', '1,890', 'AI', '1868', '1871'],
#  ['Peter Sharp', 'NA', 'NA', 'AI', '1864', '1871'],
#  ['Frederick George Shaw', 'NA', '1,918', 'AI', '1866', '1871'],
#  ['x Sheffield', '1,832', '1,909', 'AI', '1865', '1871'],
#  ['John Shortt', '1,822', '1,889', 'AI', '1863', '1871'],
#  ['Charles Lionel Showers', '1,816', '1,895', 'AI', '1862', '1871'],
#  ['Ramon de Silva-Ferro', '1,829', '1,889', 'AI', '1863', '1871'],
#  ['Frank Simpson', 'NA', 'NA', 'AI', '1865', '1871'],
#  ['James Simpson', '1,817', '1,899', 'AI', '1869', '1871'],
#  ['Frederick Mackenzie Skues', '1,834', '1,911', 'AI', '1866', '1871'],
#  ['William Mackenzie Skues', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Bath Charles Smart', '1,838', '1,887', 'AI', '1861', '1871'],
#  ['Andrew Smith', '1,797', '1,872', 'AI', '1864', '1871'],
#  ['John Smith', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Protheroe Smith', '1,809', '1,889', 'AI', '1863', '1871'],
#  ['Thomas Eustace Smith', '1,831', '1,903', 'AI', '1867', '1871'],
#  ['Thomas James Smith', '1,827', '1,896', 'AI', '1869', '1871'],
#  ['Worthington George Smith', '1,835', '1,917', 'AI', '1865', '1871'],
#  ['William Somervell', 'NA', 'NA', 'AI', '1862', '1871'],
#  ['Philip Southby', '1,843', '1,908', 'AI', '1867', '1871'],
#  ['Henry King Spark', '1,824', '1,899', 'AI', '1864', '1871'],
#  ['William Spottiswoode', '1,825', '1,883', 'AI', '1861', '1871'],
#  ['Ephraim George Squier', '1,821', '1,888', 'AI', '1852', '1871'],
#  ['George St Clair', '1,836', '1,908', 'AI', '1863', '1871'],
#  ['Spencer St John', '1,825', '1,910', 'AI', '1863', '1871'],
#  ['William Edward Stanbridge', '1,821', '1,894', 'AI', '1863', '1871'],
#  ['Japetus Steenstrup', '1,813', '1,897', 'AI', '1863', '1871'],
#  ['Carl (Karl) Steinhauer', '1,801', '1,902', 'AI', '1863', '1871'],
#  ['Charles Stenning', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['William Frederick Cowell Stepney', '1,821', '1,872', 'AI', '1867', '1871'],
#  ['N  Henry Stevens', 'NA', 'NA', 'AI', '1862', '1871'],
#  ['Alexander Patrick Stewart', '1,813', '1,883', 'AI', '1855', '1871'],
#  ['Charles Edward Stewart', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['John Stirling', '1,828', '1,870', 'AI', '1866', '1870'],
#  ['David Henry Stone', '1,812', '1,890', 'AI', '1864', '1871'],
#  ['William Story', '1,816', '1,882', 'AI', '1865', '1871'],
#  ['John Marmaduke Stourton', '1,847', '1,899', 'AI', '1867', '1871'],
#  ['James Strathern', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['Andrew Struthers', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['John William Studart', 'NA', 'NA', 'AI', '1865', '1871'],
#  ['Peter Cormac Sutherland', '1,822', '1,900', 'AI', '1871', '1871'],
#  ['Horace Swete', '1,825', 'NA', 'AI', '1869', '1871'],
#  ['Algernon Charles Swinburne', '1,837', '1,909', 'AI', '1865', '1871'],
#  ['Robert Swinhoe', '1,836', '1,877', 'AI', '1861', '1871'],
#  ['Francis Tagart', 'NA', 'NA', 'AI', '1871', '1871'],
#  ['Lawson Tait', '1,845', '1,899', 'AI', '1868', '1870'],
#  ['James Talbot de Malahide', '1,805', '1,883', 'AI', '1860', '1871'],
#  ['Richard Temple', '1,826', '1,902', 'AI', '1865', '1871'],
#  ['Edward Tenison Ryan Tenison', 'NA', '1,904', 'AI', '1863', '1871'],
#  ['John Tennant', '1,796', '1,878', 'AI', '1863', '1871'],
#  ['William, Jun Theobald', '1,829', '1,908', 'AI', '1866', '1871'],
#  ['Connop Thirlwall', '1,797', '1,875', 'AI', '1864', '1871'],
#  ['Frederick Thompson', 'NA', '1,885', 'AI', '1864', '1871'],
#  ['George C Thompson', 'NA', 'NA', 'AI', '1866', '1870'],
#  ['John Thomson', '1,837', '1,921', 'AI', '1866', '1871'],
#  ['L E Threlkeld', '1,788', '1,859', 'AI', '1854', '1871'],
#  ['Edward Thurlow', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['John Thurnam', '1,810', '1,873', 'AI', '1852', '1870'],
#  ['Richard Hill Tiddeman', '1,842', '1,917', 'AI', '1870', '1871'],
#  ['Samuel Timmins', '1,826', '1,902', 'AI', '1865', '1871'],
#  ['John Tolhurst', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Albert Tootal', '1,838', '1,893', 'AI', '1867', '1871'],
#  ['Arthur Trevelyan', 'NA', '1,880', 'AI', '1863', '1871'],
#  ['Nicolas Trubner', '1,817', '1,884', 'AI', '1863', '1871'],
#  ['Charles jun Tuckett', 'NA', '1,875', 'AI', '1864', '1871'],
#  ['Thomas Harrington Tuke', '1,826', '1,888', 'AI', '1849', '1871'],
#  ['John Underwood', 'NA', 'NA', 'AI', '1860', '1871'],
#  ['Jonas Daniel Vaughan', '1,825', '1,891', 'AI', '1865', '1871'],
#  ['William Sandys Wright Vaux', '1,818', '1,885', 'AI', '1871', '1871'],
#  ['George Venables Vernon', 'NA', '1,878', 'AI', '1863', '1871'],
#  ['Carl Vogt', '1,817', '1,895', 'AI', '1863', '1871'],
#  ['Thomas Francis Wade', '1,818', '1,895', 'AI', '1865', '1871'],
#  ['Cornelius Walford', '1,827', '1,885', 'AI', '1866', '1871'],
#  ['Charles Pyndar Beauchamp Walker', '1,817', '1,894', 'AI', '1865', '1871'],
#  ['James Sydney Walker', 'NA', '1,883', 'AI', '1854', '1871'],
#  ['Thomas Walker', '1,832', '1,896', 'AI', '1854', '1871'],
#  ['Alfred Russel Wallace', '1,823', '1,913', 'AI', '1866', '1871'],
#  ['Joshua Walmsley', '1,819', 'NA', 'AI', '1867', '1871'],
#  ['Phillipp Alexander Walther', '1,812', '1,887', 'AI', '1862', '1871'],
#  ['Ottiwell Charles Waterfield', '1,831', '1,898', 'AI', '1864', '1871'],
#  ['Samuel Watson', 'NA', 'NA', 'AI', '1863', '1871'],
#  ['Robert Watt', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['Hermann Welcker', '1,822', '1,897', 'AI', '1862', '1871'],
#  ['Hodder Michael Westropp', '1,820', '1,885', 'AI', '1863', '1871'],
#  ['James Whishaw', '1,808', '1,879', 'AI', '1846', '1871'],
#  ['x Wienecke', 'NA', 'NA', 'AI', '1862', '1871'],
#  ['John Gardner Wilkinson', '1,797', '1,875', 'AI', '1853', '1871'],
#  ['John (1) Williams', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['John Wilkins Williams', 'NA', 'NA', 'AI', '1867', '1871'],
#  ['Daniel Wilson', '1,816', '1,892', 'AI', '1863', '1871'],
#  ['Frank Wilson', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['Alfred Wiltshire', '1,839', '1,886', 'AI', '1868', '1871'],
#  ['William Smith Windham', 'NA', 'NA', 'AI', '1866', '1871'],
#  ['Henry Hoyte Winwood', '1,831', '1,920', 'AI', '1869', '1871'],
#  ['Thomas Alexander Wise', '1,801', '1,889', 'AI', '1866', '1871'],
#  ['James Wodderspoon', 'NA', 'NA', 'AI', '1869', '1871'],
#  ['Francis George Cornelius Wolber', 'NA', 'NA', 'AI', '1868', '1871'],
#  ['Samuel Wood', 'NA', '1,879', 'AI', '1860', '1871'],
#  ['William Spicer Wood', 'NA', '1,902', 'AI', '1863', '1871'],
#  ['Robert Carr Woods', '1,816', '1,875', 'AI', '1863', '1871'],
#  ['Francis Beresford Wright', '1,837', '1,911', 'AI', '1870', '1871'],
#  ['Thomas Wright', '1,810', '1,877', 'AI', '1853', '1871'],
#  ['Robert Younge', '1,801', '1,874', 'AI', '1865', '1871'],
#  ['Arthur de Zeltner', 'NA', 'NA', 'AI', '1865', '1871']]

# %%
edges
# Out:
# [('H R Adam', 'AI'),
#  ('William (2) Adams', 'AI'),
#  ('Louis Agassiz', 'AI'),
#  ('Alexander Muirhead Aitken', 'AI'),
#  ('William Amhurst Tyssen Amhurst', 'AI'),
#  ('x Antrim', 'AI'),
#  ('William Appleyard', 'AI'),
#  ('William Arbuthnot', 'AI'),
#  ('William Armitage', 'AI'),
#  ('William Armstrong', 'AI'),
#  ('Richard Arnold', 'AI'),
#  ('William Arthur', 'AI'),
#  ('Charles Frederick Ash', 'AI'),
#  ('William Henry Ashurst', 'AI'),
#  ('Charles Atkins', 'AI'),
#  ('George Atkinson', 'AI'),
#  ('Charles Cardale Babington', 'AI'),
#  ('Edward Backhouse', 'AI'),
#  ('Carl Ernst von Baer', 'AI'),
#  ("Walter ('Badgett') Bagehot", 'AI'),
#  ('James Bain', 'AI'),
#  ('John Baker', 'AI'),
#  ('Samuel C Baker', 'AI'),
#  ('William Bailey Baker', 'AI'),
#  ('George Balfour', 'AI'),
#  ('John  Wheeldon Barnes', 'AI'),
#  ('William Roby Barr', 'AI'),
#  ('Thomas Squire Barrett', 'AI'),
#  ('George William Barrington', 'AI'),
#  ('William Edward Bartlett', 'AI'),
#  ('John Stothert Bartrum', 'AI'),
#  ('William Battye', 'AI'),
#  ('Hermann Beigel', 'AI'),
#  ('William Abraham Bell', 'AI'),
#  ('Edward Bellamy', 'AI'),
#  ('Henry Walter Bellew', 'AI'),
#  ('Thomas Bendyshe', 'AI'),
#  ('Charles Bennett', 'AI'),
#  ('George Bertram', 'AI'),
#  ('John Bilderbeck', 'AI'),
#  ('James Bischoff', 'AI'),
#  ('Andrew Black', 'AI'),
#  ('William Blackmore', 'AI'),
#  ('Henry Jules Blanc', 'AI'),
#  ('Henry George Bohn', 'AI'),
#  ('William Bollaert', 'AI'),
#  ('Louis Lucien Bonaparte', 'AI'),
#  ('George Bonavia', 'AI'),
#  ('James Bonsor', 'AI'),
#  ('James Bonwick', 'AI'),
#  ('Cunningham Borthwick', 'AI'),
#  ('Sydney Edward Bouverie Bouverie-Pusey', 'AI'),
#  ('Jacob Boys', 'AI'),
#  ('Edward William Brabrook', 'AI'),
#  ('Frederick Braby', 'AI'),
#  ('Charles Holt Bracebridge', 'AI'),
#  ('Antonio Brady', 'AI'),
#  ('P A Brady', 'AI'),
#  ('William Bragge', 'AI'),
#  ('A C Brebner', 'AI'),
#  ('James Brebner', 'AI'),
#  ('Charles Brett', 'AI'),
#  ('John Briggs', 'AI'),
#  ('Lindsay Brine', 'AI'),
#  ('Charles Cornish Brown', 'AI'),
#  ('James Roberts Brown', 'AI'),
#  ('John Allen Brown', 'AI'),
#  ('Thomas Henry Browne', 'AI'),
#  ('George Bryant', 'AI'),
#  ('William Bull', 'AI'),
#  ('Luke Burke', 'AI'),
#  ('George Busk', 'AI'),
#  ('William John Busteed', 'AI'),
#  ('Henry Butler', 'AI'),
#  ('James Butler', 'AI'),
#  ('Benjamin Bond Cabbell', 'AI'),
#  ('John Calman', 'AI'),
#  ('Archibald Campbell', 'AI'),
#  ('Francis Campbell', 'AI'),
#  ('George (1) Campbell', 'AI'),
#  ('James Campbell', 'AI'),
#  ('T A Campbell', 'AI'),
#  ('Walter Campbell', 'AI'),
#  ('William Camps', 'AI'),
#  ('Charles Napoleon de Cardi', 'AI'),
#  ('William D Carey', 'AI'),
#  ('John Burford Carlill', 'AI'),
#  ('Samuel Cartwright', 'AI'),
#  ('George Catlin', 'AI'),
#  ('John Cavafy', 'AI'),
#  ('John Henry Challis', 'AI'),
#  ('William Chamberlin', 'AI'),
#  ('Charles Harcourt Chambers', 'AI'),
#  ('William Chambers', 'AI'),
#  ('Frank Chance', 'AI'),
#  ('Edward Charlesworth', 'AI'),
#  ('William Charlton', 'AI'),
#  ('William Dinsdale Child', 'AI'),
#  ('Samuel Chinnery', 'AI'),
#  ('William Nathan Chipperfield', 'AI'),
#  ('T J Cholmondeley', 'AI'),
#  ('Hyde Clarke', 'AI'),
#  ('Robert Clarke', 'AI'),
#  ('William Aloysius Clavering', 'AI'),
#  ('John (1) Cleghorn', 'AI'),
#  ('H Clerk', 'AI'),
#  ('John Colam', 'AI'),
#  ('Henry Cole', 'AI'),
#  ('Vicat Cole', 'AI'),
#  ('John Sherrard Coleman', 'AI'),
#  ('John Frederick Collingwood', 'AI'),
#  ('W W Collins', 'AI'),
#  ('John (1) Collinson', 'AI'),
#  ('Moncure Daniel Conway', 'AI'),
#  ('William Fothergill Cooke', 'AI'),
#  ('Daniel Cooper', 'AI'),
#  ('Frederick Cooper', 'AI'),
#  ('William C Copperthwaite', 'AI'),
#  ('Tullie Cornthwaite', 'AI'),
#  ('Frederick William Cosens', 'AI'),
#  ('Samuel Courtauld', 'AI'),
#  ('Henry Augustus Cowper', 'AI'),
#  ('Tom junr Craston', 'AI'),
#  ('Oswald John Crawfurd', 'AI'),
#  ('Henry Crowley', 'AI'),
#  ('Moore A Cuffe', 'AI'),
#  ('Richard Cull', 'AI'),
#  ('Richard S Cunliffe', 'AI'),
#  ('Alexander Cunningham', 'AI'),
#  ('Edward Barrett Hodges Curteis', 'AI'),
#  ('John Richmond Cuthbert', 'AI'),
#  ('George Cutler', 'AI'),
#  ("William Barrington D'Almeida", 'AI'),
#  ('x Daa', 'AI'),
#  ('G  Wythes Daniell', 'AI'),
#  ('Robert Dukinfield Darbishire', 'AI'),
#  ('George Russell Dartnell', 'AI'),
#  ('Charles Darwin', 'AI'),
#  ('Arthur Dashwood', 'AI'),
#  ('John Davidson', 'AI'),
#  ('Jesse Conway Davies', 'AI'),
#  ('William Davies', 'AI'),
#  ('George Henry Daw', 'AI'),
#  ('William Boyd Dawkins', 'AI'),
#  ('George Dawson', 'AI'),
#  ('x Derby (formerly Stanley)', 'AI'),
#  ('x Devonshire', 'AI'),
#  ('George Dibley', 'AI'),
#  ('Charles Wentworth Dilke', 'AI'),
#  ('John Dingle', 'AI'),
#  ('Jacob Ludwig Dohne', 'AI'),
#  ('John Langdon H Down', 'AI'),
#  ('D I Drakeford', 'AI'),
#  ('John Drummond', 'AI'),
#  ('Alexander Duncan', 'AI'),
#  ('David Duncan', 'AI'),
#  ('Francis Duncan', 'AI'),
#  ('Peter Martin Duncan', 'AI'),
#  ('Alfred John Dunkin', 'AI'),
#  ('Robert Dunn', 'AI'),
#  ('William Eassie', 'AI'),
#  ('Joseph William Eastwood', 'AI'),
#  ('Casper W Eddy', 'AI'),
#  ('John Edwards', 'AI'),
#  ('Walter Elliot', 'AI'),
#  ('C H  Fairfax Ellis', 'AI'),
#  ('William Erle', 'AI'),
#  ('Edward Bickerton Evans', 'AI'),
#  ('John Evans', 'AI'),
#  ('Edward John Eyre', 'AI'),
#  ('William Fairbairn', 'AI'),
#  ('Adam Storey Farrar', 'AI'),
#  ('Frederick Fearon', 'AI'),
#  ('Edwin Foxton Firby', 'AI'),
#  ('Frederick Firebrace', 'AI'),
#  ('James Firm', 'AI'),
#  ('Robert Fischer', 'AI'),
#  ('Morton Coates Fisher', 'AI'),
#  ('George Fleming', 'AI'),
#  ('John Wickham Flower', 'AI'),
#  ('George Folsom', 'AI'),
#  ('David Forbes', 'AI'),
#  ('Robert Nicholas Fowler', 'AI'),
#  ('Charles Henry Fox', 'AI'),
#  ('William Henry Francklyne', 'AI'),
#  ('Augustus Wollaston Franks', 'AI'),
#  ('Thomas Fraser', 'AI'),
#  ('William Freund', 'AI'),
#  ('Danby Palmer Fry', 'AI'),
#  ('A  de Fullner', 'AI'),
#  ('Albert Fytche', 'AI'),
#  ('Douglas Galton', 'AI'),
#  ('Francis Galton', 'AI'),
#  ('C T Gardner', 'AI'),
#  ('Charles Henry Gardner', 'AI'),
#  ('E V Gardner', 'AI'),
#  ('Peter Gardner', 'AI'),
#  ('John Peter Gassiot', 'AI'),
#  ('George Duncan Gibb', 'AI'),
#  ('Enrico Hillyer Giglioli', 'AI'),
#  ('William Gillespie', 'AI'),
#  ('Spyridon Glaucopides', 'AI'),
#  ('Augustus Goldsmid', 'AI'),
#  ('Richard Thomas Gore', 'AI'),
#  ('James Gowans', 'AI'),
#  ('Ryves William Graves', 'AI'),
#  ('Frederick King Green', 'AI'),
#  ('George Courthope Green', 'AI'),
#  ('William Greenwell', 'AI'),
#  ('William Rathbone Greg', 'AI'),
#  ('Walter Gregor', 'AI'),
#  ('George Grey', 'AI'),
#  ('Henry Rowland Ellison Grey', 'AI'),
#  ('Lepel Griffin', 'AI'),
#  ('James Oliff Griffits', 'AI'),
#  ('William Vernon Guise', 'AI'),
#  ('James Guthrie', 'AI'),
#  ("Johann Franz ('Julius') Haast", 'AI'),
#  ('Alexander C Hamilton', 'AI'),
#  ('Archibald Hamilton', 'AI'),
#  ('Rowland Hamilton', 'AI'),
#  ('Richard Davis Hanson', 'AI'),
#  ('Clarence Harcourt', 'AI'),
#  ('William Harding', 'AI'),
#  ('Samuel Harraden', 'AI'),
#  ('Arthur B Harris', 'AI'),
#  ('James Penn Harris', 'AI'),
#  ('Charles (1) Harrison', 'AI'),
#  ('William Henry Harrison', 'AI'),
#  ('Alfred Edmund Harriss', 'AI'),
#  ('John E Harvey', 'AI'),
#  ('Frederick Augustus Haserick', 'AI'),
#  ('George Hawkins', 'AI'),
#  ('Ferdinand Vandeveer Hayden', 'AI'),
#  ('Edward Charles Healey', 'AI'),
#  ('Dunbar Isidore Heath', 'AI'),
#  ('G J D Heath', 'AI'),
#  ('Alexander Henderson', 'AI'),
#  ('David Mitchell Henderson', 'AI'),
#  ('P Henderson', 'AI'),
#  ('Joseph Henry', 'AI'),
#  ('Robert Hepburn', 'AI'),
#  ('John Mason Hepworth', 'AI'),
#  ('Matthew Heslop', 'AI'),
#  ('B Hewitt', 'AI'),
#  ('Alfred Hewlett', 'AI'),
#  ('James Heywood', 'AI'),
#  ('James Higgin', 'AI'),
#  ('Alfred Higgins', 'AI'),
#  ('R  Harvey Hilliard', 'AI'),
#  ('Frederick Hindmarsh', 'AI'),
#  ('W G E Hobbs', 'AI'),
#  ('Brian Houghton Hodgson', 'AI'),
#  ('Kirkman Daniel Hodgson', 'AI'),
#  ('Carl Alphonse Hoffman', 'AI'),
#  ('Joseph Hooker', 'AI'),
#  ('James Hope', 'AI'),
#  ('John Camden Hotten', 'AI'),
#  ('Frederick Hovenden', 'AI'),
#  ('W T Howard', 'AI'),
#  ('Henry Hoyle Howorth', 'AI'),
#  ('Henry Hudson', 'AI'),
#  ('Thomas McKenny Hughes', 'AI'),
#  ('John (2) Hunt', 'AI'),
#  ('William Wilson Hunter', 'AI'),
#  ('Jonathan Hutchinson', 'AI'),
#  ('Thomas Henry Huxley', 'AI'),
#  ('John Inglis', 'AI'),
#  ('x Isenburg', 'AI'),
#  ('Henry (the son) Jackson', 'AI'),
#  ('Henry William (1) Jackson', 'AI'),
#  ('J W Jackson', 'AI'),
#  ('Horatio Gay James', 'AI'),
#  ('John Moore Jeffcott', 'AI'),
#  ('Frederick John Jeffery', 'AI'),
#  ('Edmund Jeffries', 'AI'),
#  ('William Jennings', 'AI'),
#  ('Leonard Jenyns LATER Blomefield', 'AI'),
#  ('William Jepson', 'AI'),
#  ('George Curling Joad', 'AI'),
#  ('Arthur Johnson', 'AI'),
#  ('x Johore', 'AI'),
#  ('James Jones', 'AI'),
#  ('William Arthur Jones', 'AI'),
#  ('J W  (2) Kaye', 'AI'),
#  ('Claude Buchanan Ker', 'AI'),
#  ('Nicolai de Khanikof', 'AI'),
#  ('Joshua Edward Killick', 'AI'),
#  ('William Kincaid', 'AI'),
#  ('Edwin Holborow King', 'AI'),
#  ('Richard King', 'AI'),
#  ('Charles Kingsley', 'AI'),
#  ('David Kinloch', 'AI'),
#  ('Richard Kirwan', 'AI'),
#  ('J L Knapp', 'AI'),
#  ('William White La Barte', 'AI'),
#  ('Samuel Laing', 'AI'),
#  ('Thomas Josiah Laing', 'AI'),
#  ('John Lancaster', 'AI'),
#  ('Augustus Henry Lane Fox later Pitt Rivers', 'AI'),
#  ('Andrew Lang', 'AI'),
#  ('J Langlands', 'AI'),
#  ('Robert Gordon Latham', 'AI'),
#  ('Edward Lawford', 'AI'),
#  ('Austen Henry Layard', 'AI'),
#  ('John Edward Lee', 'AI'),
#  ('Samuel Lees', 'AI'),
#  ('Joseph Leidy', 'AI'),
#  ('Henry Leighton', 'AI'),
#  ('Arthur Charles Wriothesley Lennox', 'AI'),
#  ('Richard Lepsius', 'AI'),
#  ('Karl Georg Friedrich Rudolf Leuckart', 'AI'),
#  ('William Lockhart', 'AI'),
#  ('Abraham Logan', 'AI'),
#  ('J R Logan', 'AI'),
#  ('William Long', 'AI'),
#  ('Edward Lord', 'AI'),
#  ('Horatio Love', 'AI'),
#  ('Basil Lovery', 'AI'),
#  ('John Lubbock', 'AI'),
#  ('Johann Constantin August Lucae', 'AI'),
#  ('William Collings Lukis', 'AI'),
#  ('John Alfred Lush', 'AI'),
#  ('Coryndon H Luxmoore', 'AI'),
#  ('John Macartney', 'AI'),
#  ('John Gray Macfarlane', 'AI'),
#  ('G Macgowan', 'AI'),
#  ('Draper Mackinder', 'AI'),
#  ('David Mackintosh', 'AI'),
#  ('Hector Maclean', 'AI'),
#  ('George Macleay', 'AI'),
#  ('Andrew Maclure', 'AI'),
#  ('William Elphinstone Malcolm', 'AI'),
#  ('Robert James Mann', 'AI'),
#  ('Clements Robert Markham', 'AI'),
#  ('Matthew Henry Marsh', 'AI'),
#  ('Edward W Martin', 'AI'),
#  ('John (2) Martin', 'AI'),
#  ('Richard Biddulph Martin', 'AI'),
#  ('James Wood Mason', 'AI'),
#  ('James Mathieson', 'AI'),
#  ('Henry Matthews', 'AI'),
#  ('Alfred Maury', 'AI'),
#  ('Peter Benson Maxwell', 'AI'),
#  ('Edward Hooper May', 'AI'),
#  ('Joseph Mayer', 'AI'),
#  ('William Frederick Mayers', 'AI'),
#  ('John S Mayson', 'AI'),
#  ('James McClelland', 'AI'),
#  ('John McCormick', 'AI'),
#  ('John McDonnell', 'AI'),
#  ('John Ferguson McLennan', 'AI'),
#  ('Walter McLeod', 'AI'),
#  ('John Frederick McNair', 'AI'),
#  ('Barr Meadows', 'AI'),
#  ('Charles William Carter Madden Medlicott', 'AI'),
#  ('James Aitken Meigs', 'AI'),
#  ('John Magens Mello', 'AI'),
#  ('Evan Powell Meredith', 'AI'),
#  ('Alexander Michie', 'AI'),
#  ('William Augustus Miles', 'AI'),
#  ('John Miller', 'AI'),
#  ('Joseph Milligan', 'AI'),
#  ('Henry F Mills', 'AI'),
#  ('Henri Milne-Edwards', 'AI'),
#  ('x Milton', 'AI'),
#  ('Albert Mitchell', 'AI'),
#  ('Alexander (1) Mitchell', 'AI'),
#  ('Matthew Moggridge', 'AI'),
#  ('Frederick Butler Montgomerie', 'AI'),
#  ('John Moody', 'AI'),
#  ('George Moore', 'AI'),
#  ('Henry Reginald Moore', 'AI'),
#  ('John (1) Moore', 'AI'),
#  ('John (2) Moore', 'AI'),
#  ('Robert Waters Moore', 'AI'),
#  ('Fortescue John Morgan', 'AI'),
#  ('William Henry Morgan', 'AI'),
#  ('James Cotter Morison', 'AI'),
#  ('Edward Rowley Morris', 'AI'),
#  ('Eugene Morris', 'AI'),
#  ('John Morris', 'AI'),
#  ('James Holmes Morrison', 'AI'),
#  ('Walter Morrison', 'AI'),
#  ('John Mortimer', 'AI'),
#  ('John Robert Mortimer', 'AI'),
#  ('Henry Muirhead', 'AI'),
#  ('Friedrich Max Muller', 'AI'),
#  ('Francis Kerridge Munton', 'AI'),
#  ('J C Murray', 'AI'),
#  ('Charles Ottley Groom Napier', 'AI'),
#  ('William Napier', 'AI'),
#  ('Davyd William Nash', 'AI'),
#  ('Samuel Nash', 'AI'),
#  ('J  Dormer Neale', 'AI'),
#  ('Robert Stirling (1) Newall', 'AI'),
#  ('P H Newnham', 'AI'),
#  ('Alfred Vincent Newton', 'AI'),
#  ('Thomas Nicholas', 'AI'),
#  ('Brinsley Nicholson', 'AI'),
#  ('Charles Nicholson', 'AI'),
#  ('Giustiniano Nicolucci', 'AI'),
#  ('Sven Nilsson', 'AI'),
#  ('Karl Friedrich Nordmann', 'AI'),
#  ('Henry Norsworthy', 'AI'),
#  ('Samuel William North', 'AI'),
#  ('Josiah Clark Nott', 'AI'),
#  ('John Nottingham', 'AI'),
#  ('Richard Maddock Nunn', 'AI'),
#  ("P O'Callaghan", 'AI'),
#  ("Luke Smyth O'Connor", 'AI'),
#  ("Edward O'Riley", 'AI'),
#  ('Samuel Pasfield Oliver', 'AI'),
#  ('Gustav Oppert', 'AI'),
#  ('John Benn Ormathwaite', 'AI'),
#  ('W  Billing Orton', 'AI'),
#  ('Sherard Osborn', 'AI'),
#  ('John William Willoughby Osborne', 'AI'),
#  ('Charles Otto', 'AI'),
#  ('Frederick Ouvry', 'AI'),
#  ('John Fletcher Owen', 'AI'),
#  ('Richard Owen', 'AI'),
#  ('Robert Brisco Owen', 'AI'),
#  ('Samuel R J Owen', 'AI'),
#  ('William Gifford Palgrave', 'AI'),
#  ('Walter Mantell Parker', 'AI'),
#  ('J  Charlton Parr', 'AI'),
#  ("Theodore D'Orville Partridge", 'AI'),
#  ('Edmund Patterson', 'AI'),
#  ('R W Payne', 'AI'),
#  ('Thomas Bevill Peacock', 'AI'),
#  ('Alfred Henry Pechell', 'AI'),
#  ('Robert Peel', 'AI'),
#  ('John Peiser', 'AI'),
#  ('William Peppe', 'AI'),
#  ('Josef Anton Maximilian Perty', 'AI'),
#  ('Horace William Petherick', 'AI'),
#  ('Arthur Phayre', 'AI'),
#  ('Philip Phoebus', 'AI'),
#  ('Charles Pickering', 'AI'),
#  ('Francois Jules Pictet', 'AI'),
#  ('Bedford Pim', 'AI'),
#  ('John Platts', 'AI'),
#  ('Matthew Conway Poole', 'AI'),
#  ('Joseph Legg Postlethwaite', 'AI'),
#  ('Joseph Prestwich', 'AI'),
#  ('Frederick George Hilton Price', 'AI'),
#  ('Lorenzo T C Price', 'AI'),
#  ('Thomas Prichard', 'AI'),
#  ('Henry jun Prigg', 'AI'),
#  ('Alfred Pulford', 'AI'),
#  ('Arthur Giles Puller', 'AI'),
#  ('Bernard Quaritch', 'AI'),
#  ('Lambert Adolphe Jacques Quetelet', 'AI'),
#  ('James Rae', 'AI'),
#  ('A , jun Ramsay', 'AI'),
#  ('John Ramsay', 'AI'),
#  ('William Francis Ramsay', 'AI'),
#  ('Jabez Spence Ramskill', 'AI'),
#  ('Edwin Ransom', 'AI'),
#  ('Goday Naraen Gajapati Rao', 'AI'),
#  ('Charles Ratcliff', 'AI'),
#  ('Henry Rawlinson', 'AI'),
#  ('Lestock Robert Reid', 'AI'),
#  ('Ernest Renan', 'AI'),
#  ('Charles Jeremiah Renshaw', 'AI'),
#  ('Edward Jackson Riccard', 'AI'),
#  ('Franklin Thomas Richards', 'AI'),
#  ('Charles Richardson', 'AI'),
#  ('Francis Richardson', 'AI'),
#  ('George Thorne Ricketts', 'AI'),
#  ('x Ripon, De Grey and', 'AI'),
#  ('John Henry Rivett-Carnac', 'AI'),
#  ('Charles Robert des Ruffieres', 'AI'),
#  ('Daniel Brooke Robertson', 'AI'),
#  ('Edward Robinson', 'AI'),
#  ('William Robinson', 'AI'),
#  ('Sampson Roch', 'AI'),
#  ('George Rogers', 'AI'),
#  ('George Rolleston', 'AI'),
#  ('Hyacinthe Ronay', 'AI'),
#  ('Charles Rooke', 'AI'),
#  ('James Anderson Rose', 'AI'),
#  ('x Rosehill', 'AI'),
#  ('John George Clunies Ross', 'AI'),
#  ('Ankithum Venkata Nursing Row', 'AI'),
#  ('Harry Crommelin Rowcroft', 'AI'),
#  ('Frederick William Rudler', 'AI'),
#  ('H  Hodgson Rugg', 'AI'),
#  ('John Ruskin', 'AI'),
#  ('A H Russell', 'AI'),
#  ('Charles E Russell', 'AI'),
#  ('Edward Ryan', 'AI'),
#  ('Oluf Rygh', 'AI'),
#  ('David Salomons', 'AI'),
#  ('William Severin Salting', 'AI'),
#  ('Alfred Sanders', 'AI'),
#  ('W  Walbank Sanderson', 'AI'),
#  ('W H Scattergood', 'AI'),
#  ('William Mason Scharlieb', 'AI'),
#  ('Carl Ritter von Scherzer', 'AI'),
#  ('E Schiemann', 'AI'),
#  ('John (2) Scott', 'AI'),
#  ('Robert S Scott', 'AI'),
#  ('Thomas Scott', 'AI'),
#  ('John Scouler', 'AI'),
#  ('Lucy Ellen Sewall', 'AI'),
#  ('Peter Sharp', 'AI'),
#  ('Frederick George Shaw', 'AI'),
#  ('x Sheffield', 'AI'),
#  ('John Shortt', 'AI'),
#  ('Charles Lionel Showers', 'AI'),
#  ('Ramon de Silva-Ferro', 'AI'),
#  ('Frank Simpson', 'AI'),
#  ('James Simpson', 'AI'),
#  ('Frederick Mackenzie Skues', 'AI'),
#  ('William Mackenzie Skues', 'AI'),
#  ('Bath Charles Smart', 'AI'),
#  ('Andrew Smith', 'AI'),
#  ('John Smith', 'AI'),
#  ('Protheroe Smith', 'AI'),
#  ('Thomas Eustace Smith', 'AI'),
#  ('Thomas James Smith', 'AI'),
#  ('Worthington George Smith', 'AI'),
#  ('William Somervell', 'AI'),
#  ('Philip Southby', 'AI'),
#  ('Henry King Spark', 'AI'),
#  ('William Spottiswoode', 'AI'),
#  ('Ephraim George Squier', 'AI'),
#  ('George St Clair', 'AI'),
#  ('Spencer St John', 'AI'),
#  ('William Edward Stanbridge', 'AI'),
#  ('Japetus Steenstrup', 'AI'),
#  ('Carl (Karl) Steinhauer', 'AI'),
#  ('Charles Stenning', 'AI'),
#  ('William Frederick Cowell Stepney', 'AI'),
#  ('N  Henry Stevens', 'AI'),
#  ('Alexander Patrick Stewart', 'AI'),
#  ('Charles Edward Stewart', 'AI'),
#  ('John Stirling', 'AI'),
#  ('David Henry Stone', 'AI'),
#  ('William Story', 'AI'),
#  ('John Marmaduke Stourton', 'AI'),
#  ('James Strathern', 'AI'),
#  ('Andrew Struthers', 'AI'),
#  ('John William Studart', 'AI'),
#  ('Peter Cormac Sutherland', 'AI'),
#  ('Horace Swete', 'AI'),
#  ('Algernon Charles Swinburne', 'AI'),
#  ('Robert Swinhoe', 'AI'),
#  ('Francis Tagart', 'AI'),
#  ('Lawson Tait', 'AI'),
#  ('James Talbot de Malahide', 'AI'),
#  ('Richard Temple', 'AI'),
#  ('Edward Tenison Ryan Tenison', 'AI'),
#  ('John Tennant', 'AI'),
#  ('William, Jun Theobald', 'AI'),
#  ('Connop Thirlwall', 'AI'),
#  ('Frederick Thompson', 'AI'),
#  ('George C Thompson', 'AI'),
#  ('John Thomson', 'AI'),
#  ('L E Threlkeld', 'AI'),
#  ('Edward Thurlow', 'AI'),
#  ('John Thurnam', 'AI'),
#  ('Richard Hill Tiddeman', 'AI'),
#  ('Samuel Timmins', 'AI'),
#  ('John Tolhurst', 'AI'),
#  ('Albert Tootal', 'AI'),
#  ('Arthur Trevelyan', 'AI'),
#  ('Nicolas Trubner', 'AI'),
#  ('Charles jun Tuckett', 'AI'),
#  ('Thomas Harrington Tuke', 'AI'),
#  ('John Underwood', 'AI'),
#  ('Jonas Daniel Vaughan', 'AI'),
#  ('William Sandys Wright Vaux', 'AI'),
#  ('George Venables Vernon', 'AI'),
#  ('Carl Vogt', 'AI'),
#  ('Thomas Francis Wade', 'AI'),
#  ('Cornelius Walford', 'AI'),
#  ('Charles Pyndar Beauchamp Walker', 'AI'),
#  ('James Sydney Walker', 'AI'),
#  ('Thomas Walker', 'AI'),
#  ('Alfred Russel Wallace', 'AI'),
#  ('Joshua Walmsley', 'AI'),
#  ('Phillipp Alexander Walther', 'AI'),
#  ('Ottiwell Charles Waterfield', 'AI'),
#  ('Samuel Watson', 'AI'),
#  ('Robert Watt', 'AI'),
#  ('Hermann Welcker', 'AI'),
#  ('Hodder Michael Westropp', 'AI'),
#  ('James Whishaw', 'AI'),
#  ('x Wienecke', 'AI'),
#  ('John Gardner Wilkinson', 'AI'),
#  ('John (1) Williams', 'AI'),
#  ('John Wilkins Williams', 'AI'),
#  ('Daniel Wilson', 'AI'),
#  ('Frank Wilson', 'AI'),
#  ('Alfred Wiltshire', 'AI'),
#  ('William Smith Windham', 'AI'),
#  ('Henry Hoyte Winwood', 'AI'),
#  ('Thomas Alexander Wise', 'AI'),
#  ('James Wodderspoon', 'AI'),
#  ('Francis George Cornelius Wolber', 'AI'),
#  ('Samuel Wood', 'AI'),
#  ('William Spicer Wood', 'AI'),
#  ('Robert Carr Woods', 'AI'),
#  ('Francis Beresford Wright', 'AI'),
#  ('Thomas Wright', 'AI'),
#  ('Robert Younge', 'AI'),
#  ('Arthur de Zeltner', 'AI')]

# %%
print(len(node_names))
print(len(edges))
# Out:
# 610
# 610

# %%
print("First 5 nodes:", node_names[0:5])
print("First 5 edges:", edges[0:5])
# Out:
# First 5 nodes: ['H R Adam', 'William (2) Adams', 'Louis Agassiz', 'Alexander Muirhead Aitken', 'William Amhurst Tyssen Amhurst']
# First 5 edges: [('H R Adam', 'AI'), ('William (2) Adams', 'AI'), ('Louis Agassiz', 'AI'), ('Alexander Muirhead Aitken', 'AI'), ('William Amhurst Tyssen Amhurst', 'AI')]

# %%
G = nx.Graph()
G.add_nodes_from(node_names)
G.add_edges_from(edges)
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 611
# Number of edges: 610
# Average degree:   1.9967

# %%
# Nodes

birth_year_dict = {}
death_year_dict = {}
Target_dict = {}
first_year_dict = {}
last_year_dict = {}

# %%
for node in nodes: # Loop through the list, one row at a time
    
    birth_year_dict [node[0]] = node[1]
    death_year_dict [node[0]] = node[2]
    Target_dict [node[0]] = node[3]
    first_year_dict[node[0]] = node[4]
    last_year_dict[node[0]] = node[5]

# %%
# Nodes
nx.set_node_attributes(G, birth_year_dict, 'birth_year')
nx.set_node_attributes(G, death_year_dict, 'death_year')
nx.set_node_attributes(G, Target_dict, 'Target')
nx.set_node_attributes(G, first_year_dict, 'first_year')
nx.set_node_attributes(G, last_year_dict, 'last_year')

# %%
for n in G.nodes(): # Loop through every node, in our data "n" will be the name of the person
    print(n, G.nodes[n]['Target']) # Access every node by its name, and then by the attribute "birth_year"
# Out:
# H R Adam AI
# William (2) Adams AI
# Louis Agassiz AI
# Alexander Muirhead Aitken AI
# William Amhurst Tyssen Amhurst AI
# x Antrim AI
# William Appleyard AI
# William Arbuthnot AI
# William Armitage AI
# William Armstrong AI
# Richard Arnold AI
# William Arthur AI
# Charles Frederick Ash AI
# William Henry Ashurst AI
# Charles Atkins AI
# George Atkinson AI
# Charles Cardale Babington AI
# Edward Backhouse AI
# Carl Ernst von Baer AI
# Walter ('Badgett') Bagehot AI
# James Bain AI
# John Baker AI
# Samuel C Baker AI
# William Bailey Baker AI
# George Balfour AI
# John  Wheeldon Barnes AI
# William Roby Barr AI
# Thomas Squire Barrett AI
# George William Barrington AI
# William Edward Bartlett AI
# John Stothert Bartrum AI
# William Battye AI
# Hermann Beigel AI
# William Abraham Bell AI
# Edward Bellamy AI
# Henry Walter Bellew AI
# Thomas Bendyshe AI
# Charles Bennett AI
# George Bertram AI
# John Bilderbeck AI
# James Bischoff AI
# Andrew Black AI
# William Blackmore AI
# Henry Jules Blanc AI
# Henry George Bohn AI
# William Bollaert AI
# Louis Lucien Bonaparte AI
# George Bonavia AI
# James Bonsor AI
# James Bonwick AI
# Cunningham Borthwick AI
# Sydney Edward Bouverie Bouverie-Pusey AI
# Jacob Boys AI
# Edward William Brabrook AI
# Frederick Braby AI
# Charles Holt Bracebridge AI
# Antonio Brady AI
# P A Brady AI
# William Bragge AI
# A C Brebner AI
# James Brebner AI
# Charles Brett AI
# John Briggs AI
# Lindsay Brine AI
# Charles Cornish Brown AI
# James Roberts Brown AI
# John Allen Brown AI
# Thomas Henry Browne AI
# George Bryant AI
# William Bull AI
# Luke Burke AI
# George Busk AI
# William John Busteed AI
# Henry Butler AI
# James Butler AI
# Benjamin Bond Cabbell AI
# John Calman AI
# Archibald Campbell AI
# Francis Campbell AI
# George (1) Campbell AI
# James Campbell AI
# T A Campbell AI
# Walter Campbell AI
# William Camps AI
# Charles Napoleon de Cardi AI
# William D Carey AI
# John Burford Carlill AI
# Samuel Cartwright AI
# George Catlin AI
# John Cavafy AI
# John Henry Challis AI
# William Chamberlin AI
# Charles Harcourt Chambers AI
# William Chambers AI
# Frank Chance AI
# Edward Charlesworth AI
# William Charlton AI
# William Dinsdale Child AI
# Samuel Chinnery AI
# William Nathan Chipperfield AI
# T J Cholmondeley AI
# Hyde Clarke AI
# Robert Clarke AI
# William Aloysius Clavering AI
# John (1) Cleghorn AI
# H Clerk AI
# John Colam AI
# Henry Cole AI
# Vicat Cole AI
# John Sherrard Coleman AI
# John Frederick Collingwood AI
# W W Collins AI
# John (1) Collinson AI
# Moncure Daniel Conway AI
# William Fothergill Cooke AI
# Daniel Cooper AI
# Frederick Cooper AI
# William C Copperthwaite AI
# Tullie Cornthwaite AI
# Frederick William Cosens AI
# Samuel Courtauld AI
# Henry Augustus Cowper AI
# Tom junr Craston AI
# Oswald John Crawfurd AI
# Henry Crowley AI
# Moore A Cuffe AI
# Richard Cull AI
# Richard S Cunliffe AI
# Alexander Cunningham AI
# Edward Barrett Hodges Curteis AI
# John Richmond Cuthbert AI
# George Cutler AI
# William Barrington D'Almeida AI
# x Daa AI
# G  Wythes Daniell AI
# Robert Dukinfield Darbishire AI
# George Russell Dartnell AI
# Charles Darwin AI
# Arthur Dashwood AI
# John Davidson AI
# Jesse Conway Davies AI
# William Davies AI
# George Henry Daw AI
# William Boyd Dawkins AI
# George Dawson AI
# x Derby (formerly Stanley) AI
# x Devonshire AI
# George Dibley AI
# Charles Wentworth Dilke AI
# John Dingle AI
# Jacob Ludwig Dohne AI
# John Langdon H Down AI
# D I Drakeford AI
# John Drummond AI
# Alexander Duncan AI
# David Duncan AI
# Francis Duncan AI
# Peter Martin Duncan AI
# Alfred John Dunkin AI
# Robert Dunn AI
# William Eassie AI
# Joseph William Eastwood AI
# Casper W Eddy AI
# John Edwards AI
# Walter Elliot AI
# C H  Fairfax Ellis AI
# William Erle AI
# Edward Bickerton Evans AI
# John Evans AI
# Edward John Eyre AI
# William Fairbairn AI
# Adam Storey Farrar AI
# Frederick Fearon AI
# Edwin Foxton Firby AI
# Frederick Firebrace AI
# James Firm AI
# Robert Fischer AI
# Morton Coates Fisher AI
# George Fleming AI
# John Wickham Flower AI
# George Folsom AI
# David Forbes AI
# Robert Nicholas Fowler AI
# Charles Henry Fox AI
# William Henry Francklyne AI
# Augustus Wollaston Franks AI
# Thomas Fraser AI
# William Freund AI
# Danby Palmer Fry AI
# A  de Fullner AI
# Albert Fytche AI
# Douglas Galton AI
# Francis Galton AI
# C T Gardner AI
# Charles Henry Gardner AI
# E V Gardner AI
# Peter Gardner AI
# John Peter Gassiot AI
# George Duncan Gibb AI
# Enrico Hillyer Giglioli AI
# William Gillespie AI
# Spyridon Glaucopides AI
# Augustus Goldsmid AI
# Richard Thomas Gore AI
# James Gowans AI
# Ryves William Graves AI
# Frederick King Green AI
# George Courthope Green AI
# William Greenwell AI
# William Rathbone Greg AI
# Walter Gregor AI
# George Grey AI
# Henry Rowland Ellison Grey AI
# Lepel Griffin AI
# James Oliff Griffits AI
# William Vernon Guise AI
# James Guthrie AI
# Johann Franz ('Julius') Haast AI
# Alexander C Hamilton AI
# Archibald Hamilton AI
# Rowland Hamilton AI
# Richard Davis Hanson AI
# Clarence Harcourt AI
# William Harding AI
# Samuel Harraden AI
# Arthur B Harris AI
# James Penn Harris AI
# Charles (1) Harrison AI
# William Henry Harrison AI
# Alfred Edmund Harriss AI
# John E Harvey AI
# Frederick Augustus Haserick AI
# George Hawkins AI
# Ferdinand Vandeveer Hayden AI
# Edward Charles Healey AI
# Dunbar Isidore Heath AI
# G J D Heath AI
# Alexander Henderson AI
# David Mitchell Henderson AI
# P Henderson AI
# Joseph Henry AI
# Robert Hepburn AI
# John Mason Hepworth AI
# Matthew Heslop AI
# B Hewitt AI
# Alfred Hewlett AI
# James Heywood AI
# James Higgin AI
# Alfred Higgins AI
# R  Harvey Hilliard AI
# Frederick Hindmarsh AI
# W G E Hobbs AI
# Brian Houghton Hodgson AI
# Kirkman Daniel Hodgson AI
# Carl Alphonse Hoffman AI
# Joseph Hooker AI
# James Hope AI
# John Camden Hotten AI
# Frederick Hovenden AI
# W T Howard AI
# Henry Hoyle Howorth AI
# Henry Hudson AI
# Thomas McKenny Hughes AI
# John (2) Hunt AI
# William Wilson Hunter AI
# Jonathan Hutchinson AI
# Thomas Henry Huxley AI
# John Inglis AI
# x Isenburg AI
# Henry (the son) Jackson AI
# Henry William (1) Jackson AI
# J W Jackson AI
# Horatio Gay James AI
# John Moore Jeffcott AI
# Frederick John Jeffery AI
# Edmund Jeffries AI
# William Jennings AI
# Leonard Jenyns LATER Blomefield AI
# William Jepson AI
# George Curling Joad AI
# Arthur Johnson AI
# x Johore AI
# James Jones AI
# William Arthur Jones AI
# J W  (2) Kaye AI
# Claude Buchanan Ker AI
# Nicolai de Khanikof AI
# Joshua Edward Killick AI
# William Kincaid AI
# Edwin Holborow King AI
# Richard King AI
# Charles Kingsley AI
# David Kinloch AI
# Richard Kirwan AI
# J L Knapp AI
# William White La Barte AI
# Samuel Laing AI
# Thomas Josiah Laing AI
# John Lancaster AI
# Augustus Henry Lane Fox later Pitt Rivers AI
# Andrew Lang AI
# J Langlands AI
# Robert Gordon Latham AI
# Edward Lawford AI
# Austen Henry Layard AI
# John Edward Lee AI
# Samuel Lees AI
# Joseph Leidy AI
# Henry Leighton AI
# Arthur Charles Wriothesley Lennox AI
# Richard Lepsius AI
# Karl Georg Friedrich Rudolf Leuckart AI
# William Lockhart AI
# Abraham Logan AI
# J R Logan AI
# William Long AI
# Edward Lord AI
# Horatio Love AI
# Basil Lovery AI
# John Lubbock AI
# Johann Constantin August Lucae AI
# William Collings Lukis AI
# John Alfred Lush AI
# Coryndon H Luxmoore AI
# John Macartney AI
# John Gray Macfarlane AI
# G Macgowan AI
# Draper Mackinder AI
# David Mackintosh AI
# Hector Maclean AI
# George Macleay AI
# Andrew Maclure AI
# William Elphinstone Malcolm AI
# Robert James Mann AI
# Clements Robert Markham AI
# Matthew Henry Marsh AI
# Edward W Martin AI
# John (2) Martin AI
# Richard Biddulph Martin AI
# James Wood Mason AI
# James Mathieson AI
# Henry Matthews AI
# Alfred Maury AI
# Peter Benson Maxwell AI
# Edward Hooper May AI
# Joseph Mayer AI
# William Frederick Mayers AI
# John S Mayson AI
# James McClelland AI
# John McCormick AI
# John McDonnell AI
# John Ferguson McLennan AI
# Walter McLeod AI
# John Frederick McNair AI
# Barr Meadows AI
# Charles William Carter Madden Medlicott AI
# James Aitken Meigs AI
# John Magens Mello AI
# Evan Powell Meredith AI
# Alexander Michie AI
# William Augustus Miles AI
# John Miller AI
# Joseph Milligan AI
# Henry F Mills AI
# Henri Milne-Edwards AI
# x Milton AI
# Albert Mitchell AI
# Alexander (1) Mitchell AI
# Matthew Moggridge AI
# Frederick Butler Montgomerie AI
# John Moody AI
# George Moore AI
# Henry Reginald Moore AI
# John (1) Moore AI
# John (2) Moore AI
# Robert Waters Moore AI
# Fortescue John Morgan AI
# William Henry Morgan AI
# James Cotter Morison AI
# Edward Rowley Morris AI
# Eugene Morris AI
# John Morris AI
# James Holmes Morrison AI
# Walter Morrison AI
# John Mortimer AI
# John Robert Mortimer AI
# Henry Muirhead AI
# Friedrich Max Muller AI
# Francis Kerridge Munton AI
# J C Murray AI
# Charles Ottley Groom Napier AI
# William Napier AI
# Davyd William Nash AI
# Samuel Nash AI
# J  Dormer Neale AI
# Robert Stirling (1) Newall AI
# P H Newnham AI
# Alfred Vincent Newton AI
# Thomas Nicholas AI
# Brinsley Nicholson AI
# Charles Nicholson AI
# Giustiniano Nicolucci AI
# Sven Nilsson AI
# Karl Friedrich Nordmann AI
# Henry Norsworthy AI
# Samuel William North AI
# Josiah Clark Nott AI
# John Nottingham AI
# Richard Maddock Nunn AI
# P O'Callaghan AI
# Luke Smyth O'Connor AI
# Edward O'Riley AI
# Samuel Pasfield Oliver AI
# Gustav Oppert AI
# John Benn Ormathwaite AI
# W  Billing Orton AI
# Sherard Osborn AI
# John William Willoughby Osborne AI
# Charles Otto AI
# Frederick Ouvry AI
# John Fletcher Owen AI
# Richard Owen AI
# Robert Brisco Owen AI
# Samuel R J Owen AI
# William Gifford Palgrave AI
# Walter Mantell Parker AI
# J  Charlton Parr AI
# Theodore D'Orville Partridge AI
# Edmund Patterson AI
# R W Payne AI
# Thomas Bevill Peacock AI
# Alfred Henry Pechell AI
# Robert Peel AI
# John Peiser AI
# William Peppe AI
# Josef Anton Maximilian Perty AI
# Horace William Petherick AI
# Arthur Phayre AI
# Philip Phoebus AI
# Charles Pickering AI
# Francois Jules Pictet AI
# Bedford Pim AI
# John Platts AI
# Matthew Conway Poole AI
# Joseph Legg Postlethwaite AI
# Joseph Prestwich AI
# Frederick George Hilton Price AI
# Lorenzo T C Price AI
# Thomas Prichard AI
# Henry jun Prigg AI
# Alfred Pulford AI
# Arthur Giles Puller AI
# Bernard Quaritch AI
# Lambert Adolphe Jacques Quetelet AI
# James Rae AI
# A , jun Ramsay AI
# John Ramsay AI
# William Francis Ramsay AI
# Jabez Spence Ramskill AI
# Edwin Ransom AI
# Goday Naraen Gajapati Rao AI
# Charles Ratcliff AI
# Henry Rawlinson AI
# Lestock Robert Reid AI
# Ernest Renan AI
# Charles Jeremiah Renshaw AI
# Edward Jackson Riccard AI
# Franklin Thomas Richards AI
# Charles Richardson AI
# Francis Richardson AI
# George Thorne Ricketts AI
# x Ripon, De Grey and AI
# John Henry Rivett-Carnac AI
# Charles Robert des Ruffieres AI
# Daniel Brooke Robertson AI
# Edward Robinson AI
# William Robinson AI
# Sampson Roch AI
# George Rogers AI
# George Rolleston AI
# Hyacinthe Ronay AI
# Charles Rooke AI
# James Anderson Rose AI
# x Rosehill AI
# John George Clunies Ross AI
# Ankithum Venkata Nursing Row AI
# Harry Crommelin Rowcroft AI
# Frederick William Rudler AI
# H  Hodgson Rugg AI
# John Ruskin AI
# A H Russell AI
# Charles E Russell AI
# Edward Ryan AI
# Oluf Rygh AI
# David Salomons AI
# William Severin Salting AI
# Alfred Sanders AI
# W  Walbank Sanderson AI
# W H Scattergood AI
# William Mason Scharlieb AI
# Carl Ritter von Scherzer AI
# E Schiemann AI
# John (2) Scott AI
# Robert S Scott AI
# Thomas Scott AI
# John Scouler AI
# Lucy Ellen Sewall AI
# Peter Sharp AI
# Frederick George Shaw AI
# x Sheffield AI
# John Shortt AI
# Charles Lionel Showers AI
# Ramon de Silva-Ferro AI
# Frank Simpson AI
# James Simpson AI
# Frederick Mackenzie Skues AI
# William Mackenzie Skues AI
# Bath Charles Smart AI
# Andrew Smith AI
# John Smith AI
# Protheroe Smith AI
# Thomas Eustace Smith AI
# Thomas James Smith AI
# Worthington George Smith AI
# William Somervell AI
# Philip Southby AI
# Henry King Spark AI
# William Spottiswoode AI
# Ephraim George Squier AI
# George St Clair AI
# Spencer St John AI
# William Edward Stanbridge AI
# Japetus Steenstrup AI
# Carl (Karl) Steinhauer AI
# Charles Stenning AI
# William Frederick Cowell Stepney AI
# N  Henry Stevens AI
# Alexander Patrick Stewart AI
# Charles Edward Stewart AI
# John Stirling AI
# David Henry Stone AI
# William Story AI
# John Marmaduke Stourton AI
# James Strathern AI
# Andrew Struthers AI
# John William Studart AI
# Peter Cormac Sutherland AI
# Horace Swete AI
# Algernon Charles Swinburne AI
# Robert Swinhoe AI
# Francis Tagart AI
# Lawson Tait AI
# James Talbot de Malahide AI
# Richard Temple AI
# Edward Tenison Ryan Tenison AI
# John Tennant AI
# William, Jun Theobald AI
# Connop Thirlwall AI
# Frederick Thompson AI
# George C Thompson AI
# John Thomson AI
# L E Threlkeld AI
# Edward Thurlow AI
# John Thurnam AI
# Richard Hill Tiddeman AI
# Samuel Timmins AI
# John Tolhurst AI
# Albert Tootal AI
# Arthur Trevelyan AI
# Nicolas Trubner AI
# Charles jun Tuckett AI
# Thomas Harrington Tuke AI
# John Underwood AI
# Jonas Daniel Vaughan AI
# William Sandys Wright Vaux AI
# George Venables Vernon AI
# Carl Vogt AI
# Thomas Francis Wade AI
# Cornelius Walford AI
# Charles Pyndar Beauchamp Walker AI
# James Sydney Walker AI
# Thomas Walker AI
# Alfred Russel Wallace AI
# Joshua Walmsley AI
# Phillipp Alexander Walther AI
# Ottiwell Charles Waterfield AI
# Samuel Watson AI
# Robert Watt AI
# Hermann Welcker AI
# Hodder Michael Westropp AI
# James Whishaw AI
# x Wienecke AI
# John Gardner Wilkinson AI
# John (1) Williams AI
# John Wilkins Williams AI
# Daniel Wilson AI
# Frank Wilson AI
# Alfred Wiltshire AI
# William Smith Windham AI
# Henry Hoyte Winwood AI
# Thomas Alexander Wise AI
# James Wodderspoon AI
# Francis George Cornelius Wolber AI
# Samuel Wood AI
# William Spicer Wood AI
# Robert Carr Woods AI
# Francis Beresford Wright AI
# Thomas Wright AI
# Robert Younge AI
# Arthur de Zeltner AI
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-5e09b9a198ab> in <module>
#       1 for n in G.nodes(): # Loop through every node, in our data "n" will be the name of the person
# ----> 2     print(n, G.nodes[n]['Target']) # Access every node by its name, and then by the attribute "birth_year"
#
# KeyError: 'Target'

# %%
# nx.write_gexf(G, 'jnb_hddt_ceda_ai.gexf')
