# %% [markdown]
# # HDDT Visualisations - AI DNA Graph #

# %% [markdown]
# ## The Anthropological Institute ##
#
# The database contains the names of 1171 members of the APS from its foundation in 1838 to 1871 when it merged with Anti-Slavery International. 571 members (49%) are Quaker.

# %%
import csv
from operator import itemgetter
import networkx as nx
from networkx.algorithms import community #This part of networkx, for community detection, needs to be imported separately.

# %%
with open('vw_4_ceda_ai_quakers_202108162128.csv', 'r') as nodecsv: # Open the file
    nodereader = csv.reader(nodecsv) # Read the csv
    nodes = [n for n in nodereader][1:]  # Retrieve the data (using Python list comprhension and list slicing to remove the header row.
    
node_names = [n[0] for n in nodes] # Get a list of only the node names    

with open('vw_2_ceda_membership_xid_ai_202108162143.csv', 'r') as edgecsv: # Open the file
    edgereader = csv.reader(edgecsv) # Read the csv
    edges = [tuple(e) for e in edgereader][1:]  # Retrieve the data

# %%
nodes
# Out:
# [['H R Adam', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['William (2) Adams', '1,820', '1,900', '1858', '1871', 'NA'],
#  ['Louis Agassiz', '1,807', '1,873', '1860', '1871', 'NA'],
#  ['Alexander Muirhead Aitken', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['William Amhurst Tyssen Amhurst', '1,835', '1,909', '1862', '1871', 'NA'],
#  ['x Antrim', '1,851', '1,918', '1871', '1871', 'NA'],
#  ['William Appleyard', 'NA', 'NA', '1854', '1871', 'NA'],
#  ['William Arbuthnot', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['William Armitage', '1,815', '1,903', '1864', '1871', 'NA'],
#  ['William Armstrong', '1,810', '1,900', '1865', '1871', 'NA'],
#  ['Richard Arnold', '1,808', '1,876', '1866', '1871', 'NA'],
#  ['William Arthur', '1,819', '1,901', '1865', '1870', 'NA'],
#  ['Charles Frederick Ash', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['William Henry Ashurst', '1,819', '1,879', '1863', '1871', 'NA'],
#  ['Charles Atkins', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['George Atkinson', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['Charles Cardale Babington', '1,808', '1,895', '1864', '1871', 'NA'],
#  ['Edward Backhouse', '1,808', '1,879', '1870', '1871', '1'],
#  ['Carl Ernst von Baer', '1,792', '1,876', '1861', '1871', 'NA'],
#  ["Walter ('Badgett') Bagehot", '1,826', '1,877', '1865', '1871', 'NA'],
#  ['James Bain', '1,818', '1,898', '1865', '1871', 'NA'],
#  ['John Baker', '1,813', '1,872', '1861', '1871', 'NA'],
#  ['Samuel C Baker', '1,821', '1,893', '1866', '1871', 'NA'],
#  ['William Bailey Baker', '1,828', '1,865', '1858', '1871', 'NA'],
#  ['George Balfour', '1,809', '1,894', '1865', '1871', 'NA'],
#  ['John  Wheeldon Barnes', '1,825', '1,893', '1870', '1871', 'NA'],
#  ['William Roby Barr', '1,832', 'NA', '1863', '1871', 'NA'],
#  ['Thomas Squire Barrett', 'NA', 'NA', '1865', '1871', 'NA'],
#  ['George William Barrington', '1,824', '1,886', '1865', '1871', 'NA'],
#  ['William Edward Bartlett', '1,836', '1,908', '1864', '1871', 'NA'],
#  ['John Stothert Bartrum', '1,817', '1,904', '1865', '1871', 'NA'],
#  ['William Battye', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Hermann Beigel', '1,830', '1,879', '1865', '1871', 'NA'],
#  ['William Abraham Bell', '1,841', '1,921', '1869', '1871', 'NA'],
#  ['Edward Bellamy', '1,837', '1,889', '1865', '1871', 'NA'],
#  ['Henry Walter Bellew', '1,834', '1,892', '1870', '1871', 'NA'],
#  ['Thomas Bendyshe', '1,827', '1,886', '1863', '1871', 'NA'],
#  ['Charles Bennett', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['George Bertram', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['John Bilderbeck', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['James Bischoff', 'NA', 'NA', '1865', '1871', 'NA'],
#  ['Andrew Black', '1,851', '1,916', '1870', '1871', 'NA'],
#  ['William Blackmore', '1,827', '1,878', '1866', '1871', 'NA'],
#  ['Henry Jules Blanc', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['Henry George Bohn', '1,796', '1,884', '1861', '1871', 'NA'],
#  ['William Bollaert', '1,807', '1,876', '1862', '1870', 'NA'],
#  ['Louis Lucien Bonaparte', '1,813', '1,891', '1862', '1871', 'NA'],
#  ['George Bonavia', '1,818', '1,901', '1870', '1871', 'NA'],
#  ['James Bonsor', 'NA', '1,881', '1869', '1871', 'NA'],
#  ['James Bonwick', '1,817', '1,906', '1869', '1871', 'NA'],
#  ['Cunningham Borthwick', '1,813', '1,885', '1865', '1871', 'NA'],
#  ['Sydney Edward Bouverie Bouverie-Pusey',
#   '1,839',
#   '1,911',
#   '1863',
#   '1871',
#   'NA'],
#  ['Jacob Boys', '1,796', '1,884', '1863', '1871', 'NA'],
#  ['Edward William Brabrook', '1,839', '1,930', '1864', '1871', 'NA'],
#  ['Frederick Braby', '1,830', '1,911', '1865', '1871', 'NA'],
#  ['Charles Holt Bracebridge', '1,799', '1,872', '1844', '1871', 'NA'],
#  ['Antonio Brady', '1,811', '1,881', '1864', '1871', '1'],
#  ['P A Brady', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['William Bragge', '1,823', '1,884', '1870', '1871', 'NA'],
#  ['A C Brebner', 'NA', '1,873', '1867', '1871', 'NA'],
#  ['James Brebner', '1,793', '1,874', '1863', '1871', 'NA'],
#  ['Charles Brett', 'NA', '1,878', '1865', '1871', 'NA'],
#  ['John Briggs', '1,785', '1,875', '1845', '1871', 'NA'],
#  ['Lindsay Brine', '1,834', '1,906', '1869', '1871', 'NA'],
#  ['Charles Cornish Brown', '1,846', '1,875', '1871', '1871', 'NA'],
#  ['James Roberts Brown', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['John Allen Brown', '1,831', '1,903', '1865', '1871', 'NA'],
#  ['Thomas Henry Browne', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['George Bryant', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['William Bull', '1,828', '1,902', '1867', '1871', '1'],
#  ['Luke Burke', 'NA', '1,885', '1861', '1864', 'NA'],
#  ['George Busk', '1,807', '1,886', '1863', '1871', 'NA'],
#  ['William John Busteed', '1,836', '1,914', '1867', '1871', 'NA'],
#  ['Henry Butler', '1,838', 'NA', '1864', '1871', 'NA'],
#  ['James Butler', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Benjamin Bond Cabbell', '1,782', '1,874', '1864', '1871', 'NA'],
#  ['John Calman', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['Archibald Campbell', '1,805', '1,874', '1866', '1871', 'NA'],
#  ['Francis Campbell', '1,798', '1,877', '1866', '1871', 'NA'],
#  ['George (1) Campbell', '1,824', '1,892', '1869', '1870', 'NA'],
#  ['James Campbell', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['T A Campbell', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['Walter Campbell', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['William Camps', 'NA', '1,887', '1845', '1871', 'NA'],
#  ['Charles Napoleon de Cardi', '1,844', '1,906', '1868', '1871', 'NA'],
#  ['William D Carey', '1,837', '1,917', '1865', '1871', 'NA'],
#  ['John Burford Carlill', '1,814', '1,874', '1867', '1871', 'NA'],
#  ['Samuel Cartwright', '1,789', '1,864', '1863', '1871', 'NA'],
#  ['George Catlin', '1,796', '1,872', '1866', '1871', 'NA'],
#  ['John Cavafy', '1,838', '1,901', '1865', '1871', 'NA'],
#  ['John Henry Challis', '1,806', '1,880', '1865', '1871', 'NA'],
#  ['William Chamberlin', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Charles Harcourt Chambers', '1,826', '1,876', '1863', '1871', 'NA'],
#  ['William Chambers', '1,809', '1,882', '1864', '1871', 'NA'],
#  ['Frank Chance', '1,825', '1,897', '1863', '1871', 'NA'],
#  ['Edward Charlesworth', '1,813', '1,893', '1866', '1871', 'NA'],
#  ['William Charlton', '1,814', '1,880', '1865', '1871', 'NA'],
#  ['William Dinsdale Child', 'NA', '1,879', '1844', '1871', 'NA'],
#  ['Samuel Chinnery', '1,828', 'NA', '1865', '1871', 'NA'],
#  ['William Nathan Chipperfield', '1,822', '1,873', '1865', '1871', 'NA'],
#  ['T J Cholmondeley', '1,818', '1,883', '1868', '1871', 'NA'],
#  ['Hyde Clarke', '1,815', '1,895', '1864', '1867', 'NA'],
#  ['Robert Clarke', 'NA', 'NA', '1862', '1871', 'NA'],
#  ['William Aloysius Clavering', '1,800', '1,872', '1861', '1871', 'NA'],
#  ['John (1) Cleghorn', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['H Clerk', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['John Colam', '1,827', '1,910', '1870', '1871', 'NA'],
#  ['Henry Cole', '1,808', '1,882', '1864', '1871', 'NA'],
#  ['Vicat Cole', '1,833', '1,893', '1865', '1871', 'NA'],
#  ['John Sherrard Coleman', '1,828', '1,905', '1854', '1871', 'NA'],
#  ['John Frederick Collingwood', '1,830', '1,923', '1863', '1871', 'NA'],
#  ['W W Collins', 'NA', '1,880', '1862', '1871', 'NA'],
#  ['John (1) Collinson', '1,842', '1,922', '1866', '1871', 'NA'],
#  ['Moncure Daniel Conway', '1,832', '1,907', '1869', '1871', 'NA'],
#  ['William Fothergill Cooke', '1,806', '1,879', '1864', '1871', 'NA'],
#  ['Daniel Cooper', '1,821', '1,902', '1863', '1871', 'NA'],
#  ['Frederick Cooper', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['William C Copperthwaite', '1,809', '1,890', '1867', '1871', 'NA'],
#  ['Tullie Cornthwaite', '1,807', 'NA', '1846', '1871', 'NA'],
#  ['Frederick William Cosens', '1,819', '1,889', '1864', '1871', 'NA'],
#  ['Samuel Courtauld', '1,793', '1,881', '1864', '1871', 'NA'],
#  ['Henry Augustus Cowper', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['Tom junr Craston', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['Oswald John Crawfurd', '1,834', '1,909', '1861', '1871', 'NA'],
#  ['Henry Crowley', 'NA', '1,887', '1864', '1871', '1'],
#  ['Moore A Cuffe', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['Richard Cull', 'NA', '1,892', '1845', '1857', 'NA'],
#  ['Richard S Cunliffe', 'NA', '1,879', '1855', '1871', 'NA'],
#  ['Alexander Cunningham', '1,814', '1,893', '1869', '1871', 'NA'],
#  ['Edward Barrett Hodges Curteis', 'NA', '1,886', '1867', '1871', 'NA'],
#  ['John Richmond Cuthbert', 'NA', '1,901', '1863', '1871', 'NA'],
#  ['George Cutler', 'NA', 'NA', '1860', '1871', 'NA'],
#  ["William Barrington D'Almeida", '1,841', '1,897', '1867', '1871', 'NA'],
#  ['x Daa', '1,809', '1,877', '1866', '1871', 'NA'],
#  ['G  Wythes Daniell', 'NA', 'NA', '1858', '1871', 'NA'],
#  ['Robert Dukinfield Darbishire', '1,826', '1,908', '1869', '1871', 'NA'],
#  ['George Russell Dartnell', '1,799', '1,878', '1867', '1871', 'NA'],
#  ['Charles Darwin', '1,809', '1,882', '1861', '1871', 'NA'],
#  ['Arthur Dashwood', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['John Davidson', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Jesse Conway Davies', '1,822', 'NA', '1866', '1871', 'NA'],
#  ['William Davies', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['George Henry Daw', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['William Boyd Dawkins', '1,837', '1,929', '1869', '1871', 'NA'],
#  ['George Dawson', '1,821', '1,876', '1863', '1871', 'NA'],
#  ['x Derby (formerly Stanley)', '1,841', '1,908', '1864', '1871', 'NA'],
#  ['x Devonshire', '1,808', '1,891', '1862', '1871', 'NA'],
#  ['George Dibley', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['Charles Wentworth Dilke', '1,843', '1,911', '1870', '1871', 'NA'],
#  ['John Dingle', '1,812', '1,885', '1863', '1871', 'NA'],
#  ['Jacob Ludwig Dohne', '1,811', '1,879', '1856', '1871', 'NA'],
#  ['John Langdon H Down', '1,828', '1,896', '1865', '1871', 'NA'],
#  ['D I Drakeford', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['John Drummond', '1,793', '1,875', '1864', '1871', 'NA'],
#  ['Alexander Duncan', '1,819', '1,887', '1868', '1871', 'NA'],
#  ['David Duncan', '1,839', '1,923', '1870', '1871', 'NA'],
#  ['Francis Duncan', '1,836', '1,888', '1867', '1871', 'NA'],
#  ['Peter Martin Duncan', '1,824', '1,891', '1869', '1869', 'NA'],
#  ['Alfred John Dunkin', '1,812', '1,879', '1868', '1871', 'NA'],
#  ['Robert Dunn', '1,799', '1,877', '1845', '1871', 'NA'],
#  ['William Eassie', '1,832', '1,888', '1864', '1871', 'NA'],
#  ['Joseph William Eastwood', '1,828', '1,916', '1862', '1871', 'NA'],
#  ['Casper W Eddy', 'NA', 'NA', '1868', '1868', 'NA'],
#  ['John Edwards', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['Walter Elliot', '1,803', '1,887', '1869', '1871', 'NA'],
#  ['C H  Fairfax Ellis', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['William Erle', '1,793', '1,880', '1863', '1871', 'NA'],
#  ['Edward Bickerton Evans', '1,819', '1,893', '1864', '1871', 'NA'],
#  ['John Evans', '1,823', '1,908', '1863', '1871', 'NA'],
#  ['Edward John Eyre', '1,815', '1,901', '1864', '1871', 'NA'],
#  ['William Fairbairn', '1,789', '1,874', '1867', '1871', 'NA'],
#  ['Adam Storey Farrar', '1,826', '1,905', '1870', '1871', 'NA'],
#  ['Frederick Fearon', '1,826', 'NA', '1864', '1871', 'NA'],
#  ['Edwin Foxton Firby', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['Frederick Firebrace', 'NA', '1,917', '1864', '1871', 'NA'],
#  ['James Firm', 'NA', 'NA', '1854', '1871', 'NA'],
#  ['Robert Fischer', 'NA', '1,911', '1866', '1871', 'NA'],
#  ['Morton Coates Fisher', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['George Fleming', '1,833', '1,901', '1863', '1871', 'NA'],
#  ['John Wickham Flower', '1,807', '1,873', '1869', '1871', 'NA'],
#  ['George Folsom', '1,802', '1,869', '1866', '1869', 'NA'],
#  ['David Forbes', '1,828', '1,876', '1868', '1871', 'NA'],
#  ['Robert Nicholas Fowler', '1,828', '1,891', '1851', '1871', '1'],
#  ['Charles Henry Fox', 'NA', 'NA', '1861', '1871', '1'],
#  ['William Henry Francklyne', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['Augustus Wollaston Franks', '1,826', '1,897', '1863', '1871', 'NA'],
#  ['Thomas Fraser', '1,808', '1,891', '1865', '1871', 'NA'],
#  ['William Freund', '1,806', '1,894', '1853', '1871', 'NA'],
#  ['Danby Palmer Fry', '1,818', '1,903', '1863', '1864', 'NA'],
#  ['A  de Fullner', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['Albert Fytche', '1,820', '1,892', '1866', '1871', 'NA'],
#  ['Douglas Galton', '1,822', '1,899', '1861', '1871', 'NA'],
#  ['Francis Galton', '1,822', '1,911', '1862', '1871', 'NA'],
#  ['C T Gardner', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['Charles Henry Gardner', 'NA', '1,872', '1864', '1871', 'NA'],
#  ['E V Gardner', 'NA', 'NA', '1861', '1871', 'NA'],
#  ['Peter Gardner', 'NA', '1,872', '1846', '1871', 'NA'],
#  ['John Peter Gassiot', '1,797', '1,877', '1862', '1871', 'NA'],
#  ['George Duncan Gibb', '1,821', '1,876', '1863', '1871', 'NA'],
#  ['Enrico Hillyer Giglioli', '1,845', '1,909', '1862', '1871', 'NA'],
#  ['William Gillespie', 'NA', '1,875', '1865', '1871', 'NA'],
#  ['Spyridon Glaucopides', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Augustus Goldsmid', '1,818', '1,874', '1865', '1871', 'NA'],
#  ['Richard Thomas Gore', '1,799', '1,881', '1860', '1869', 'NA'],
#  ['James Gowans', '1,821', '1,890', '1866', '1871', 'NA'],
#  ['Ryves William Graves', 'NA', '1,882', '1867', '1871', 'NA'],
#  ['Frederick King Green', '1,842', '1,915', '1869', '1871', 'NA'],
#  ['George Courthope Green', 'NA', '1,875', '1867', '1871', 'NA'],
#  ['William Greenwell', '1,820', '1,918', '1868', '1869', 'NA'],
#  ['William Rathbone Greg', '1,809', '1,881', '1865', '1871', 'NA'],
#  ['Walter Gregor', '1,825', '1,897', '1863', '1871', 'NA'],
#  ['George Grey', '1,812', '1,898', '1860', '1871', 'NA'],
#  ['Henry Rowland Ellison Grey', '1,834', '1,909', '1861', '1871', 'NA'],
#  ['Lepel Griffin', '1,838', '1,908', '1866', '1871', 'NA'],
#  ['James Oliff Griffits', '1,821', 'NA', '1866', '1871', 'NA'],
#  ['William Vernon Guise', '1,816', '1,887', '1869', '1871', 'NA'],
#  ['James Guthrie', 'NA', '1,900', '1862', '1871', 'NA'],
#  ["Johann Franz ('Julius') Haast", '1,822', '1,887', '1870', '1871', 'NA'],
#  ['Alexander C Hamilton', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['Archibald Hamilton', '1,818', '1,880', '1863', '1871', 'NA'],
#  ['Rowland Hamilton', 'NA', 'NA', '1853', '1871', 'NA'],
#  ['Richard Davis Hanson', '1,805', '1,876', '1870', '1871', 'NA'],
#  ['Clarence Harcourt', 'NA', '1,909', '1864', '1871', 'NA'],
#  ['William Harding', '1,809', '1,890', '1865', '1871', 'NA'],
#  ['Samuel Harraden', 'NA', 'NA', '1865', '1871', 'NA'],
#  ['Arthur B Harris', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['James Penn Harris', '1,817', '1,892', '1867', '1871', 'NA'],
#  ['Charles (1) Harrison', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['William Henry Harrison', '1,840', '1,897', '1868', '1871', 'NA'],
#  ['Alfred Edmund Harriss', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['John E Harvey', 'NA', '1,879', '1863', '1871', 'NA'],
#  ['Frederick Augustus Haserick', '1,828', '1,902', '1866', '1871', 'NA'],
#  ['George Hawkins', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['Ferdinand Vandeveer Hayden', '1,829', '1,887', '1869', '1871', 'NA'],
#  ['Edward Charles Healey', '1,845', '1,906', '1864', '1871', 'NA'],
#  ['Dunbar Isidore Heath', '1,816', '1,888', '1864', '1871', 'NA'],
#  ['G J D Heath', 'NA', '1,880', '1869', '1871', 'NA'],
#  ['Alexander Henderson', '1,804', 'NA', '1854', '1871', 'NA'],
#  ['David Mitchell Henderson', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['P Henderson', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['Joseph Henry', '1,797', '1,878', '1869', '1871', 'NA'],
#  ['Robert Hepburn', 'NA', 'NA', '1855', '1871', 'NA'],
#  ['John Mason Hepworth', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Matthew Heslop', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['B Hewitt', 'NA', 'NA', '1871', '1871', 'NA'],
#  ['Alfred Hewlett', '1,831', '1,918', '1863', '1871', 'NA'],
#  ['James Heywood', '1,810', '1,897', '1844', '1871', 'NA'],
#  ['James Higgin', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Alfred Higgins', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['R  Harvey Hilliard', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['Frederick Hindmarsh', 'NA', '1,875', '1845', '1871', 'NA'],
#  ['W G E Hobbs', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['Brian Houghton Hodgson', '1,801', '1,894', '1863', '1871', 'NA'],
#  ['Kirkman Daniel Hodgson', '1,814', '1,879', '1863', '1871', 'NA'],
#  ['Carl Alphonse Hoffman', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['Joseph Hooker', '1,817', '1,911', '1868', '1871', 'NA'],
#  ['James Hope', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['John Camden Hotten', '1,832', '1,873', '1867', '1871', 'NA'],
#  ['Frederick Hovenden', '1,838', '1,911', '1868', '1871', 'NA'],
#  ['W T Howard', 'NA', 'NA', '1865', '1871', 'NA'],
#  ['Henry Hoyle Howorth', '1,842', '1,923', '1856', '1871', 'NA'],
#  ['Henry Hudson', 'NA', '1,889', '1864', '1871', 'NA'],
#  ['Thomas McKenny Hughes', '1,832', '1,917', '1869', '1871', 'NA'],
#  ['John (2) Hunt', 'NA', '1,879', '1866', '1871', 'NA'],
#  ['William Wilson Hunter', '1,840', '1,900', '1870', '1871', 'NA'],
#  ['Jonathan Hutchinson', '1,828', '1,913', '1863', '1871', '1'],
#  ['Thomas Henry Huxley', '1,825', '1,895', '1863', '1871', 'NA'],
#  ['John Inglis', '1,808', '1,891', '1854', '1871', 'NA'],
#  ['x Isenburg', 'NA', 'NA', '1854', '1871', 'NA'],
#  ['Henry (the son) Jackson', '1,839', '1,921', '1863', '1871', 'NA'],
#  ['Henry William (1) Jackson', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['J W Jackson', 'NA', '1,872', '1863', '1871', 'NA'],
#  ['Horatio Gay James', 'NA', 'NA', '1865', '1871', 'NA'],
#  ['John Moore Jeffcott', '1,816', '1,892', '1869', '1871', 'NA'],
#  ['Frederick John Jeffery', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['Edmund Jeffries', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['William Jennings', '1,847', '1,927', '1864', '1871', 'NA'],
#  ['Leonard Jenyns LATER Blomefield', '1,800', '1,893', '1863', '1871', 'NA'],
#  ['William Jepson', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['George Curling Joad', '1,837', '1,881', '1865', '1871', 'NA'],
#  ['Arthur Johnson', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['x Johore', '1,833', '1,895', '1866', '1871', 'NA'],
#  ['James Jones', 'NA', 'NA', '1862', '1871', 'NA'],
#  ['William Arthur Jones', '1,818', '1,873', '1869', '1871', 'NA'],
#  ['J W  (2) Kaye', '1,840', 'NA', '1868', '1871', 'NA'],
#  ['Claude Buchanan Ker', '1,867', '1,925', '1867', '1871', 'NA'],
#  ['Nicolai de Khanikof', '1,819', '1,878', '1866', '1871', 'NA'],
#  ['Joshua Edward Killick', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['William Kincaid', '1,831', '1,909', '1865', '1871', 'NA'],
#  ['Edwin Holborow King', 'NA', '1,900', '1869', '1871', 'NA'],
#  ['Richard King', '1,811', '1,876', '1866', '1871', 'NA'],
#  ['Charles Kingsley', '1,819', '1,875', '1856', '1871', 'NA'],
#  ['David Kinloch', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['Richard Kirwan', '1,828', '1,872', '1869', '1871', 'NA'],
#  ['J L Knapp', 'NA', 'NA', '1854', '1871', 'NA'],
#  ['William White La Barte', '1,824', '1,904', '1863', '1870', 'NA'],
#  ['Samuel Laing', '1,812', '1,897', '1864', '1871', 'NA'],
#  ['Thomas Josiah Laing', '1,810', '1,880', '1867', '1871', 'NA'],
#  ['John Lancaster', '1,815', '1,884', '1863', '1871', 'NA'],
#  ['Augustus Henry Lane Fox later Pitt Rivers',
#   '1,827',
#   '1,900',
#   '1865',
#   '1871',
#   'NA'],
#  ['Andrew Lang', '1,844', '1,912', '1861', '1871', 'NA'],
#  ['J Langlands', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Robert Gordon Latham', '1,812', '1,888', '1844', '1853', 'NA'],
#  ['Edward Lawford', '1,820', '1,899', '1867', '1871', 'NA'],
#  ['Austen Henry Layard', '1,817', '1,894', '1853', '1871', 'NA'],
#  ['John Edward Lee', '1,808', '1,887', '1870', '1871', 'NA'],
#  ['Samuel Lees', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Joseph Leidy', '1,823', '1,891', '1869', '1871', 'NA'],
#  ['Henry Leighton', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Arthur Charles Wriothesley Lennox', '1,842', '1,876', '1866', '1871', 'NA'],
#  ['Richard Lepsius', '1,810', '1,884', '1854', '1871', 'NA'],
#  ['Karl Georg Friedrich Rudolf Leuckart',
#   '1,822',
#   '1,898',
#   '1861',
#   '1871',
#   'NA'],
#  ['William Lockhart', '1,811', '1,896', '1861', '1871', 'NA'],
#  ['Abraham Logan', '1,816', '1,873', '1863', '1871', 'NA'],
#  ['J R Logan', '1,819', '1,869', '1866', '1869', 'NA'],
#  ['William Long', '1,817', '1,886', '1869', '1871', 'NA'],
#  ['Edward Lord', '1,812', '1,875', '1863', '1871', 'NA'],
#  ['Horatio Love', 'NA', '1,882', '1850', '1871', 'NA'],
#  ['Basil Lovery', 'NA', '1,897', '1868', '1871', 'NA'],
#  ['John Lubbock', '1,834', '1,913', '1863', '1871', 'NA'],
#  ['Johann Constantin August Lucae', '1,835', '1,911', '1861', '1871', 'NA'],
#  ['William Collings Lukis', '1,817', '1,892', '1864', '1871', 'NA'],
#  ['John Alfred Lush', '1,815', '1,888', '1869', '1871', 'NA'],
#  ['Coryndon H Luxmoore', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['John Macartney', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['John Gray Macfarlane', 'NA', 'NA', '1865', '1871', 'NA'],
#  ['G Macgowan', 'NA', 'NA', '1861', '1871', 'NA'],
#  ['Draper Mackinder', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['David Mackintosh', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Hector Maclean', '1,818', '1,893', '1867', '1871', 'NA'],
#  ['George Macleay', '1,809', '1,891', '1869', '1869', 'NA'],
#  ['Andrew Maclure', '1,813', '1,886', '1867', '1871', 'NA'],
#  ['William Elphinstone Malcolm', '1,817', '1,907', '1855', '1871', 'NA'],
#  ['Robert James Mann', '1,817', '1,886', '1866', '1871', 'NA'],
#  ['Clements Robert Markham', '1,830', '1,916', '1864', '1871', 'NA'],
#  ['Matthew Henry Marsh', '1,810', '1,881', '1862', '1871', 'NA'],
#  ['Edward W Martin', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['John (2) Martin', '1,812', '1,874', '1864', '1871', 'NA'],
#  ['Richard Biddulph Martin', '1,838', '1,916', '1868', '1871', 'NA'],
#  ['James Wood Mason', '1,846', '1,893', '1869', '1871', 'NA'],
#  ['James Mathieson', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Henry Matthews', '1,826', '1,913', '1863', '1871', 'NA'],
#  ['Alfred Maury', '1,817', '1,892', '1861', '1871', 'NA'],
#  ['Peter Benson Maxwell', '1,817', '1,893', '1867', '1871', 'NA'],
#  ['Edward Hooper May', '1,831', '1,914', '1867', '1871', 'NA'],
#  ['Joseph Mayer', '1,803', '1,886', '1854', '1871', 'NA'],
#  ['William Frederick Mayers', '1,831', '1,878', '1864', '1871', 'NA'],
#  ['John S Mayson', '1,825', 'NA', '1856', '1864', 'NA'],
#  ['James McClelland', '1,799', '1,879', '1854', '1870', 'NA'],
#  ['John McCormick', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['John McDonnell', '1,839', '1,879', '1864', '1871', 'NA'],
#  ['John Ferguson McLennan', '1,827', '1,881', '1870', '1871', 'NA'],
#  ['Walter McLeod', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['John Frederick McNair', '1,828', '1,910', '1866', '1871', 'NA'],
#  ['Barr Meadows', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Charles William Carter Madden Medlicott',
#   '1,839',
#   'NA',
#   '1867',
#   '1871',
#   'NA'],
#  ['James Aitken Meigs', '1,829', '1,879', '1861', '1871', 'NA'],
#  ['John Magens Mello', '1,836', '1,903', '1867', '1871', 'NA'],
#  ['Evan Powell Meredith', '1,811', '1,889', '1867', '1871', 'NA'],
#  ['Alexander Michie', '1,833', '1,902', '1863', '1871', 'NA'],
#  ['William Augustus Miles', 'NA', 'NA', '1851', '1871', 'NA'],
#  ['John Miller', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Joseph Milligan', '1,807', '1,884', '1863', '1871', 'NA'],
#  ['Henry F Mills', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['Henri Milne-Edwards', '1,800', '1,885', '1863', '1871', 'NA'],
#  ['x Milton', '1,839', '1,877', '1864', '1871', 'NA'],
#  ['Albert Mitchell', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['Alexander (1) Mitchell', '1,831', '1,873', '1858', '1871', 'NA'],
#  ['Matthew Moggridge', '1,803', '1,882', '1869', '1871', 'NA'],
#  ['Frederick Butler Montgomerie', '1,833', 'NA', '1864', '1871', 'NA'],
#  ['John Moody', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['George Moore', '1,803', '1,880', '1864', '1871', 'NA'],
#  ['Henry Reginald Moore', 'NA', 'NA', '1865', '1871', 'NA'],
#  ['John (1) Moore', 'NA', '1,882', '1864', '1871', 'NA'],
#  ['John (2) Moore', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['Robert Waters Moore', '1,819', '1,884', '1866', '1871', 'NA'],
#  ['Fortescue John Morgan', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['William Henry Morgan', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['James Cotter Morison', '1,832', '1,888', '1863', '1871', 'NA'],
#  ['Edward Rowley Morris', '1,828', '1,893', '1871', '1871', 'NA'],
#  ['Eugene Morris', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['John Morris', '1,823', '1,905', '1869', '1871', 'NA'],
#  ['James Holmes Morrison', '1,842', '1,917', '1869', '1871', 'NA'],
#  ['Walter Morrison', '1,836', '1,921', '1870', '1871', 'NA'],
#  ['John Mortimer', 'NA', '1,871', '1864', '1871', 'NA'],
#  ['John Robert Mortimer', '1,825', '1,911', '1870', '1871', 'NA'],
#  ['Henry Muirhead', '1,814', '1,890', '1867', '1871', 'NA'],
#  ['Friedrich Max Muller', '1,823', '1,900', '1865', '1871', 'NA'],
#  ['Francis Kerridge Munton', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['J C Murray', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Charles Ottley Groom Napier', '1,839', '1,894', '1865', '1871', 'NA'],
#  ['William Napier', '1,804', '1,879', '1868', '1871', 'NA'],
#  ['Davyd William Nash', '1,810', '1,876', '1848', '1871', 'NA'],
#  ['Samuel Nash', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['J  Dormer Neale', 'NA', '1,884', '1868', '1871', 'NA'],
#  ['Robert Stirling (1) Newall', '1,812', '1,889', '1870', '1871', 'NA'],
#  ['P H Newnham', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Alfred Vincent Newton', 'NA', 'NA', '1865', '1871', 'NA'],
#  ['Thomas Nicholas', 'NA', 'NA', '1869', '1869', 'NA'],
#  ['Brinsley Nicholson', '1,824', '1,892', '1855', '1871', 'NA'],
#  ['Charles Nicholson', '1,808', '1,903', '1858', '1865', 'NA'],
#  ['Giustiniano Nicolucci', '1,819', '1,904', '1862', '1871', 'NA'],
#  ['Sven Nilsson', '1,787', '1,883', '1860', '1871', 'NA'],
#  ['Karl Friedrich Nordmann', '1,830', 'NA', '1868', '1871', 'NA'],
#  ['Henry Norsworthy', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Samuel William North', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Josiah Clark Nott', '1,804', '1,873', '1861', '1871', 'NA'],
#  ['John Nottingham', '1,810', '1,895', '1867', '1871', 'NA'],
#  ['Richard Maddock Nunn', 'NA', '1,876', '1865', '1871', 'NA'],
#  ["P O'Callaghan", 'NA', 'NA', '1870', '1871', 'NA'],
#  ["Luke Smyth O'Connor", '1,806', '1,873', '1864', '1871', 'NA'],
#  ["Edward O'Riley", 'NA', 'NA', '1860', '1871', 'NA'],
#  ['Samuel Pasfield Oliver', '1,838', '1,907', '1868', '1869', 'NA'],
#  ['Gustav Oppert', '1,836', '1,908', '1869', '1871', 'NA'],
#  ['John Benn Ormathwaite', '1,798', '1,881', '1864', '1871', 'NA'],
#  ['W  Billing Orton', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['Sherard Osborn', '1,822', '1,875', '1867', '1871', 'NA'],
#  ['John William Willoughby Osborne', '1,833', '1,881', '1864', '1871', 'NA'],
#  ['Charles Otto', '1,795', '1,879', '1853', '1871', 'NA'],
#  ['Frederick Ouvry', '1,814', '1,881', '1869', '1871', 'NA'],
#  ['John Fletcher Owen', '1,839', '1,924', '1868', '1871', 'NA'],
#  ['Richard Owen', '1,804', '1,892', '1863', '1871', 'NA'],
#  ['Robert Brisco Owen', '1,799', '1,883', '1863', '1871', 'NA'],
#  ['Samuel R J Owen', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['William Gifford Palgrave', '1,826', '1,888', '1868', '1871', 'NA'],
#  ['Walter Mantell Parker', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['J  Charlton Parr', 'NA', 'NA', '1868', '1871', 'NA'],
#  ["Theodore D'Orville Partridge", 'NA', '1,897', '1867', '1871', 'NA'],
#  ['Edmund Patterson', 'NA', 'NA', '1860', '1871', 'NA'],
#  ['R W Payne', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['Thomas Bevill Peacock', '1,812', '1,882', '1863', '1871', 'NA'],
#  ['Alfred Henry Pechell', '1,827', '1,885', '1866', '1871', 'NA'],
#  ['Robert Peel', '1,838', '1,894', '1866', '1871', 'NA'],
#  ['John Peiser', '1,801', '1,886', '1863', '1871', 'NA'],
#  ['William Peppe', 'NA', '1,937', '1869', '1871', 'NA'],
#  ['Josef Anton Maximilian Perty', '1,804', '1,884', '1860', '1871', 'NA'],
#  ['Horace William Petherick', '1,839', '1,919', '1863', '1871', 'NA'],
#  ['Arthur Phayre', '1,812', '1,885', '1862', '1871', 'NA'],
#  ['Philip Phoebus', '1,804', '1,880', '1861', '1867', 'NA'],
#  ['Charles Pickering', '1,805', '1,878', '1861', '1871', 'NA'],
#  ['Francois Jules Pictet', '1,809', '1,872', '1860', '1871', 'NA'],
#  ['Bedford Pim', '1,826', '1,886', '1866', '1871', 'NA'],
#  ['John Platts', '1,830', '1,904', '1869', '1871', 'NA'],
#  ['Matthew Conway Poole', '1,841', '1,885', '1871', '1871', 'NA'],
#  ['Joseph Legg Postlethwaite', 'NA', '1,871', '1844', '1871', 'NA'],
#  ['Joseph Prestwich', '1,812', '1,896', '1869', '1871', 'NA'],
#  ['Frederick George Hilton Price', '1,842', '1,909', '1868', '1871', 'NA'],
#  ['Lorenzo T C Price', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['Thomas Prichard', 'NA', '1,878', '1865', '1871', 'NA'],
#  ['Henry jun Prigg', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Alfred Pulford', '1,823', '1,896', '1866', '1871', 'NA'],
#  ['Arthur Giles Puller', '1,833', '1,885', '1865', '1871', 'NA'],
#  ['Bernard Quaritch', '1,819', '1,899', '1865', '1871', 'NA'],
#  ['Lambert Adolphe Jacques Quetelet', '1,796', '1,874', '1853', '1871', 'NA'],
#  ['James Rae', 'NA', '1,891', '1864', '1871', 'NA'],
#  ['A , jun Ramsay', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['John Ramsay', '1,814', '1,892', '1867', '1871', 'NA'],
#  ['William Francis Ramsay', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Jabez Spence Ramskill', '1,825', '1,897', '1865', '1871', 'NA'],
#  ['Edwin Ransom', '1,841', '1,927', '1868', '1871', 'NA'],
#  ['Goday Naraen Gajapati Rao', '1,828', '1,903', '1866', '1871', 'NA'],
#  ['Charles Ratcliff', '1,815', '1,885', '1863', '1871', 'NA'],
#  ['Henry Rawlinson', '1,810', '1,895', '1853', '1871', 'NA'],
#  ['Lestock Robert Reid', 'NA', '1,879', '1861', '1871', 'NA'],
#  ['Ernest Renan', '1,823', '1,892', '1861', '1871', 'NA'],
#  ['Charles Jeremiah Renshaw', '1,841', '1,916', '1863', '1871', 'NA'],
#  ['Edward Jackson Riccard', 'NA', '1,872', '1867', '1871', 'NA'],
#  ['Franklin Thomas Richards', '1,847', '1,905', '1867', '1871', 'NA'],
#  ['Charles Richardson', '1,814', '1,896', '1864', '1871', 'NA'],
#  ['Francis Richardson', '1,815', '1,896', '1863', '1871', 'NA'],
#  ['George Thorne Ricketts', '1,826', '1,919', '1870', '1871', 'NA'],
#  ['x Ripon, De Grey and', '1,827', '1,909', '1850', '1871', 'NA'],
#  ['John Henry Rivett-Carnac', '1,839', '1,923', '1870', '1871', 'NA'],
#  ['Charles Robert des Ruffieres', 'NA', '1,883', '1863', '1871', 'NA'],
#  ['Daniel Brooke Robertson', '1,810', '1,881', '1864', '1871', 'NA'],
#  ['Edward Robinson', '1,794', '1,863', '1852', '1863', 'NA'],
#  ['William Robinson', 'NA', '1,880', '1865', '1871', 'NA'],
#  ['Sampson Roch', '1,829', '1,906', '1865', '1871', 'NA'],
#  ['George Rogers', '1,809', '1,891', '1867', '1871', 'NA'],
#  ['George Rolleston', '1,829', '1,881', '1860', '1871', 'NA'],
#  ['Hyacinthe Ronay', '1,814', '1,889', '1865', '1871', 'NA'],
#  ['Charles Rooke', '1,809', '1,872', '1866', '1869', 'NA'],
#  ['James Anderson Rose', '1,819', '1,890', '1868', '1871', 'NA'],
#  ['x Rosehill', '1,843', '1,891', '1870', '1871', 'NA'],
#  ['John George Clunies Ross', '1,823', '1,871', '1860', '1871', 'NA'],
#  ['Ankithum Venkata Nursing Row', '1,827', '1,892', '1870', '1871', 'NA'],
#  ['Harry Crommelin Rowcroft', '1,840', '1,876', '1861', '1871', 'NA'],
#  ['Frederick William Rudler', '1,840', '1,915', '1871', '1871', 'NA'],
#  ['H  Hodgson Rugg', '1,812', '1,891', '1867', '1871', 'NA'],
#  ['John Ruskin', '1,819', '1,900', '1864', '1871', 'NA'],
#  ['A H Russell', '1,837', '1,916', '1860', '1871', 'NA'],
#  ['Charles E Russell', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['Edward Ryan', '1,793', '1,875', '1862', '1871', 'NA'],
#  ['Oluf Rygh', '1,833', '1,899', '1866', '1871', 'NA'],
#  ['David Salomons', '1,797', '1,873', '1860', '1871', 'NA'],
#  ['William Severin Salting', '1,837', '1,905', '1863', '1871', 'NA'],
#  ['Alfred Sanders', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['W  Walbank Sanderson', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['W H Scattergood', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['William Mason Scharlieb', '1,829', '1,891', '1867', '1871', 'NA'],
#  ['Carl Ritter von Scherzer', '1,821', '1,903', '1861', '1871', 'NA'],
#  ['E Schiemann', 'NA', 'NA', '1870', '1871', 'NA'],
#  ['John (2) Scott', '1,817', '1,890', '1867', '1871', 'NA'],
#  ['Robert S Scott', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Thomas Scott', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['John Scouler', '1,804', '1,871', '1855', '1871', 'NA'],
#  ['Lucy Ellen Sewall', '1,837', '1,890', '1868', '1871', 'NA'],
#  ['Peter Sharp', 'NA', 'NA', '1864', '1871', 'NA'],
#  ['Frederick George Shaw', 'NA', '1,918', '1866', '1871', 'NA'],
#  ['x Sheffield', '1,832', '1,909', '1865', '1871', 'NA'],
#  ['John Shortt', '1,822', '1,889', '1863', '1871', 'NA'],
#  ['Charles Lionel Showers', '1,816', '1,895', '1862', '1871', 'NA'],
#  ['Ramon de Silva-Ferro', '1,829', '1,889', '1863', '1871', 'NA'],
#  ['Frank Simpson', 'NA', 'NA', '1865', '1871', 'NA'],
#  ['James Simpson', '1,817', '1,899', '1869', '1871', 'NA'],
#  ['Frederick Mackenzie Skues', '1,834', '1,911', '1866', '1871', 'NA'],
#  ['William Mackenzie Skues', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Bath Charles Smart', '1,838', '1,887', '1861', '1871', 'NA'],
#  ['Andrew Smith', '1,797', '1,872', '1864', '1871', 'NA'],
#  ['John Smith', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Protheroe Smith', '1,809', '1,889', '1863', '1871', 'NA'],
#  ['Thomas Eustace Smith', '1,831', '1,903', '1867', '1871', 'NA'],
#  ['Thomas James Smith', '1,827', '1,896', '1869', '1871', 'NA'],
#  ['Worthington George Smith', '1,835', '1,917', '1865', '1871', 'NA'],
#  ['William Somervell', 'NA', 'NA', '1862', '1871', 'NA'],
#  ['Philip Southby', '1,843', '1,908', '1867', '1871', 'NA'],
#  ['Henry King Spark', '1,824', '1,899', '1864', '1871', 'NA'],
#  ['William Spottiswoode', '1,825', '1,883', '1861', '1871', 'NA'],
#  ['Ephraim George Squier', '1,821', '1,888', '1852', '1871', 'NA'],
#  ['George St Clair', '1,836', '1,908', '1863', '1871', 'NA'],
#  ['Spencer St John', '1,825', '1,910', '1863', '1871', 'NA'],
#  ['William Edward Stanbridge', '1,821', '1,894', '1863', '1871', 'NA'],
#  ['Japetus Steenstrup', '1,813', '1,897', '1863', '1871', 'NA'],
#  ['Carl (Karl) Steinhauer', '1,801', '1,902', '1863', '1871', 'NA'],
#  ['Charles Stenning', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['William Frederick Cowell Stepney', '1,821', '1,872', '1867', '1871', 'NA'],
#  ['N  Henry Stevens', 'NA', 'NA', '1862', '1871', 'NA'],
#  ['Alexander Patrick Stewart', '1,813', '1,883', '1855', '1871', 'NA'],
#  ['Charles Edward Stewart', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['John Stirling', '1,828', '1,870', '1866', '1870', 'NA'],
#  ['David Henry Stone', '1,812', '1,890', '1864', '1871', 'NA'],
#  ['William Story', '1,816', '1,882', '1865', '1871', 'NA'],
#  ['John Marmaduke Stourton', '1,847', '1,899', '1867', '1871', 'NA'],
#  ['James Strathern', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['Andrew Struthers', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['John William Studart', 'NA', 'NA', '1865', '1871', 'NA'],
#  ['Peter Cormac Sutherland', '1,822', '1,900', '1871', '1871', 'NA'],
#  ['Horace Swete', '1,825', 'NA', '1869', '1871', 'NA'],
#  ['Algernon Charles Swinburne', '1,837', '1,909', '1865', '1871', 'NA'],
#  ['Robert Swinhoe', '1,836', '1,877', '1861', '1871', 'NA'],
#  ['Francis Tagart', 'NA', 'NA', '1871', '1871', 'NA'],
#  ['Lawson Tait', '1,845', '1,899', '1868', '1870', 'NA'],
#  ['James Talbot de Malahide', '1,805', '1,883', '1860', '1871', 'NA'],
#  ['Richard Temple', '1,826', '1,902', '1865', '1871', 'NA'],
#  ['Edward Tenison Ryan Tenison', 'NA', '1,904', '1863', '1871', 'NA'],
#  ['John Tennant', '1,796', '1,878', '1863', '1871', 'NA'],
#  ['William, Jun Theobald', '1,829', '1,908', '1866', '1871', 'NA'],
#  ['Connop Thirlwall', '1,797', '1,875', '1864', '1871', 'NA'],
#  ['Frederick Thompson', 'NA', '1,885', '1864', '1871', 'NA'],
#  ['George C Thompson', 'NA', 'NA', '1866', '1870', 'NA'],
#  ['John Thomson', '1,837', '1,921', '1866', '1871', 'NA'],
#  ['L E Threlkeld', '1,788', '1,859', '1854', '1871', 'NA'],
#  ['Edward Thurlow', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['John Thurnam', '1,810', '1,873', '1852', '1870', 'NA'],
#  ['Richard Hill Tiddeman', '1,842', '1,917', '1870', '1871', 'NA'],
#  ['Samuel Timmins', '1,826', '1,902', '1865', '1871', 'NA'],
#  ['John Tolhurst', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Albert Tootal', '1,838', '1,893', '1867', '1871', 'NA'],
#  ['Arthur Trevelyan', 'NA', '1,880', '1863', '1871', 'NA'],
#  ['Nicolas Trubner', '1,817', '1,884', '1863', '1871', 'NA'],
#  ['Charles jun Tuckett', 'NA', '1,875', '1864', '1871', 'NA'],
#  ['Thomas Harrington Tuke', '1,826', '1,888', '1849', '1871', 'NA'],
#  ['John Underwood', 'NA', 'NA', '1860', '1871', 'NA'],
#  ['Jonas Daniel Vaughan', '1,825', '1,891', '1865', '1871', 'NA'],
#  ['William Sandys Wright Vaux', '1,818', '1,885', '1871', '1871', 'NA'],
#  ['George Venables Vernon', 'NA', '1,878', '1863', '1871', 'NA'],
#  ['Carl Vogt', '1,817', '1,895', '1863', '1871', 'NA'],
#  ['Thomas Francis Wade', '1,818', '1,895', '1865', '1871', 'NA'],
#  ['Cornelius Walford', '1,827', '1,885', '1866', '1871', 'NA'],
#  ['Charles Pyndar Beauchamp Walker', '1,817', '1,894', '1865', '1871', 'NA'],
#  ['James Sydney Walker', 'NA', '1,883', '1854', '1871', 'NA'],
#  ['Thomas Walker', '1,832', '1,896', '1854', '1871', 'NA'],
#  ['Alfred Russel Wallace', '1,823', '1,913', '1866', '1871', 'NA'],
#  ['Joshua Walmsley', '1,819', 'NA', '1867', '1871', 'NA'],
#  ['Phillipp Alexander Walther', '1,812', '1,887', '1862', '1871', 'NA'],
#  ['Ottiwell Charles Waterfield', '1,831', '1,898', '1864', '1871', 'NA'],
#  ['Samuel Watson', 'NA', 'NA', '1863', '1871', 'NA'],
#  ['Robert Watt', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['Hermann Welcker', '1,822', '1,897', '1862', '1871', 'NA'],
#  ['Hodder Michael Westropp', '1,820', '1,885', '1863', '1871', 'NA'],
#  ['James Whishaw', '1,808', '1,879', '1846', '1871', 'NA'],
#  ['x Wienecke', 'NA', 'NA', '1862', '1871', 'NA'],
#  ['John Gardner Wilkinson', '1,797', '1,875', '1853', '1871', 'NA'],
#  ['John (1) Williams', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['John Wilkins Williams', 'NA', 'NA', '1867', '1871', 'NA'],
#  ['Daniel Wilson', '1,816', '1,892', '1863', '1871', 'NA'],
#  ['Frank Wilson', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['Alfred Wiltshire', '1,839', '1,886', '1868', '1871', 'NA'],
#  ['William Smith Windham', 'NA', 'NA', '1866', '1871', 'NA'],
#  ['Henry Hoyte Winwood', '1,831', '1,920', '1869', '1871', 'NA'],
#  ['Thomas Alexander Wise', '1,801', '1,889', '1866', '1871', 'NA'],
#  ['James Wodderspoon', 'NA', 'NA', '1869', '1871', 'NA'],
#  ['Francis George Cornelius Wolber', 'NA', 'NA', '1868', '1871', 'NA'],
#  ['Samuel Wood', 'NA', '1,879', '1860', '1871', 'NA'],
#  ['William Spicer Wood', 'NA', '1,902', '1863', '1871', '1'],
#  ['Robert Carr Woods', '1,816', '1,875', '1863', '1871', 'NA'],
#  ['Francis Beresford Wright', '1,837', '1,911', '1870', '1871', 'NA'],
#  ['Thomas Wright', '1,810', '1,877', '1853', '1871', 'NA'],
#  ['Robert Younge', '1,801', '1,874', '1865', '1871', 'NA'],
#  ['Arthur de Zeltner', 'NA', 'NA', '1865', '1871', 'NA']]

# %%
edges
# Out:
# [('H R Adam', 'AI'),
#  ('William (2) Adams', 'AI'),
#  ('Louis Agassiz', 'AI'),
#  ('Alexander Muirhead Aitken', 'AI'),
#  ('William Amhurst Tyssen Amhurst', 'AI'),
#  ('x Antrim', 'AI'),
#  ('William Appleyard', 'AI'),
#  ('William Arbuthnot', 'AI'),
#  ('William Armitage', 'AI'),
#  ('William Armstrong', 'AI'),
#  ('Richard Arnold', 'AI'),
#  ('William Arthur', 'AI'),
#  ('Charles Frederick Ash', 'AI'),
#  ('William Henry Ashurst', 'AI'),
#  ('Charles Atkins', 'AI'),
#  ('George Atkinson', 'AI'),
#  ('Charles Cardale Babington', 'AI'),
#  ('Edward Backhouse', 'AI'),
#  ('Carl Ernst von Baer', 'AI'),
#  ("Walter ('Badgett') Bagehot", 'AI'),
#  ('James Bain', 'AI'),
#  ('John Baker', 'AI'),
#  ('Samuel C Baker', 'AI'),
#  ('William Bailey Baker', 'AI'),
#  ('George Balfour', 'AI'),
#  ('John  Wheeldon Barnes', 'AI'),
#  ('William Roby Barr', 'AI'),
#  ('Thomas Squire Barrett', 'AI'),
#  ('George William Barrington', 'AI'),
#  ('William Edward Bartlett', 'AI'),
#  ('John Stothert Bartrum', 'AI'),
#  ('William Battye', 'AI'),
#  ('Hermann Beigel', 'AI'),
#  ('William Abraham Bell', 'AI'),
#  ('Edward Bellamy', 'AI'),
#  ('Henry Walter Bellew', 'AI'),
#  ('Thomas Bendyshe', 'AI'),
#  ('Charles Bennett', 'AI'),
#  ('George Bertram', 'AI'),
#  ('John Bilderbeck', 'AI'),
#  ('James Bischoff', 'AI'),
#  ('Andrew Black', 'AI'),
#  ('William Blackmore', 'AI'),
#  ('Henry Jules Blanc', 'AI'),
#  ('Henry George Bohn', 'AI'),
#  ('William Bollaert', 'AI'),
#  ('Louis Lucien Bonaparte', 'AI'),
#  ('George Bonavia', 'AI'),
#  ('James Bonsor', 'AI'),
#  ('James Bonwick', 'AI'),
#  ('Cunningham Borthwick', 'AI'),
#  ('Sydney Edward Bouverie Bouverie-Pusey', 'AI'),
#  ('Jacob Boys', 'AI'),
#  ('Edward William Brabrook', 'AI'),
#  ('Frederick Braby', 'AI'),
#  ('Charles Holt Bracebridge', 'AI'),
#  ('Antonio Brady', 'AI'),
#  ('P A Brady', 'AI'),
#  ('William Bragge', 'AI'),
#  ('A C Brebner', 'AI'),
#  ('James Brebner', 'AI'),
#  ('Charles Brett', 'AI'),
#  ('John Briggs', 'AI'),
#  ('Lindsay Brine', 'AI'),
#  ('Charles Cornish Brown', 'AI'),
#  ('James Roberts Brown', 'AI'),
#  ('John Allen Brown', 'AI'),
#  ('Thomas Henry Browne', 'AI'),
#  ('George Bryant', 'AI'),
#  ('William Bull', 'AI'),
#  ('Luke Burke', 'AI'),
#  ('George Busk', 'AI'),
#  ('William John Busteed', 'AI'),
#  ('Henry Butler', 'AI'),
#  ('James Butler', 'AI'),
#  ('Benjamin Bond Cabbell', 'AI'),
#  ('John Calman', 'AI'),
#  ('Archibald Campbell', 'AI'),
#  ('Francis Campbell', 'AI'),
#  ('George (1) Campbell', 'AI'),
#  ('James Campbell', 'AI'),
#  ('T A Campbell', 'AI'),
#  ('Walter Campbell', 'AI'),
#  ('William Camps', 'AI'),
#  ('Charles Napoleon de Cardi', 'AI'),
#  ('William D Carey', 'AI'),
#  ('John Burford Carlill', 'AI'),
#  ('Samuel Cartwright', 'AI'),
#  ('George Catlin', 'AI'),
#  ('John Cavafy', 'AI'),
#  ('John Henry Challis', 'AI'),
#  ('William Chamberlin', 'AI'),
#  ('Charles Harcourt Chambers', 'AI'),
#  ('William Chambers', 'AI'),
#  ('Frank Chance', 'AI'),
#  ('Edward Charlesworth', 'AI'),
#  ('William Charlton', 'AI'),
#  ('William Dinsdale Child', 'AI'),
#  ('Samuel Chinnery', 'AI'),
#  ('William Nathan Chipperfield', 'AI'),
#  ('T J Cholmondeley', 'AI'),
#  ('Hyde Clarke', 'AI'),
#  ('Robert Clarke', 'AI'),
#  ('William Aloysius Clavering', 'AI'),
#  ('John (1) Cleghorn', 'AI'),
#  ('H Clerk', 'AI'),
#  ('John Colam', 'AI'),
#  ('Henry Cole', 'AI'),
#  ('Vicat Cole', 'AI'),
#  ('John Sherrard Coleman', 'AI'),
#  ('John Frederick Collingwood', 'AI'),
#  ('W W Collins', 'AI'),
#  ('John (1) Collinson', 'AI'),
#  ('Moncure Daniel Conway', 'AI'),
#  ('William Fothergill Cooke', 'AI'),
#  ('Daniel Cooper', 'AI'),
#  ('Frederick Cooper', 'AI'),
#  ('William C Copperthwaite', 'AI'),
#  ('Tullie Cornthwaite', 'AI'),
#  ('Frederick William Cosens', 'AI'),
#  ('Samuel Courtauld', 'AI'),
#  ('Henry Augustus Cowper', 'AI'),
#  ('Tom junr Craston', 'AI'),
#  ('Oswald John Crawfurd', 'AI'),
#  ('Henry Crowley', 'AI'),
#  ('Moore A Cuffe', 'AI'),
#  ('Richard Cull', 'AI'),
#  ('Richard S Cunliffe', 'AI'),
#  ('Alexander Cunningham', 'AI'),
#  ('Edward Barrett Hodges Curteis', 'AI'),
#  ('John Richmond Cuthbert', 'AI'),
#  ('George Cutler', 'AI'),
#  ("William Barrington D'Almeida", 'AI'),
#  ('x Daa', 'AI'),
#  ('G  Wythes Daniell', 'AI'),
#  ('Robert Dukinfield Darbishire', 'AI'),
#  ('George Russell Dartnell', 'AI'),
#  ('Charles Darwin', 'AI'),
#  ('Arthur Dashwood', 'AI'),
#  ('John Davidson', 'AI'),
#  ('Jesse Conway Davies', 'AI'),
#  ('William Davies', 'AI'),
#  ('George Henry Daw', 'AI'),
#  ('William Boyd Dawkins', 'AI'),
#  ('George Dawson', 'AI'),
#  ('x Derby (formerly Stanley)', 'AI'),
#  ('x Devonshire', 'AI'),
#  ('George Dibley', 'AI'),
#  ('Charles Wentworth Dilke', 'AI'),
#  ('John Dingle', 'AI'),
#  ('Jacob Ludwig Dohne', 'AI'),
#  ('John Langdon H Down', 'AI'),
#  ('D I Drakeford', 'AI'),
#  ('John Drummond', 'AI'),
#  ('Alexander Duncan', 'AI'),
#  ('David Duncan', 'AI'),
#  ('Francis Duncan', 'AI'),
#  ('Peter Martin Duncan', 'AI'),
#  ('Alfred John Dunkin', 'AI'),
#  ('Robert Dunn', 'AI'),
#  ('William Eassie', 'AI'),
#  ('Joseph William Eastwood', 'AI'),
#  ('Casper W Eddy', 'AI'),
#  ('John Edwards', 'AI'),
#  ('Walter Elliot', 'AI'),
#  ('C H  Fairfax Ellis', 'AI'),
#  ('William Erle', 'AI'),
#  ('Edward Bickerton Evans', 'AI'),
#  ('John Evans', 'AI'),
#  ('Edward John Eyre', 'AI'),
#  ('William Fairbairn', 'AI'),
#  ('Adam Storey Farrar', 'AI'),
#  ('Frederick Fearon', 'AI'),
#  ('Edwin Foxton Firby', 'AI'),
#  ('Frederick Firebrace', 'AI'),
#  ('James Firm', 'AI'),
#  ('Robert Fischer', 'AI'),
#  ('Morton Coates Fisher', 'AI'),
#  ('George Fleming', 'AI'),
#  ('John Wickham Flower', 'AI'),
#  ('George Folsom', 'AI'),
#  ('David Forbes', 'AI'),
#  ('Robert Nicholas Fowler', 'AI'),
#  ('Charles Henry Fox', 'AI'),
#  ('William Henry Francklyne', 'AI'),
#  ('Augustus Wollaston Franks', 'AI'),
#  ('Thomas Fraser', 'AI'),
#  ('William Freund', 'AI'),
#  ('Danby Palmer Fry', 'AI'),
#  ('A  de Fullner', 'AI'),
#  ('Albert Fytche', 'AI'),
#  ('Douglas Galton', 'AI'),
#  ('Francis Galton', 'AI'),
#  ('C T Gardner', 'AI'),
#  ('Charles Henry Gardner', 'AI'),
#  ('E V Gardner', 'AI'),
#  ('Peter Gardner', 'AI'),
#  ('John Peter Gassiot', 'AI'),
#  ('George Duncan Gibb', 'AI'),
#  ('Enrico Hillyer Giglioli', 'AI'),
#  ('William Gillespie', 'AI'),
#  ('Spyridon Glaucopides', 'AI'),
#  ('Augustus Goldsmid', 'AI'),
#  ('Richard Thomas Gore', 'AI'),
#  ('James Gowans', 'AI'),
#  ('Ryves William Graves', 'AI'),
#  ('Frederick King Green', 'AI'),
#  ('George Courthope Green', 'AI'),
#  ('William Greenwell', 'AI'),
#  ('William Rathbone Greg', 'AI'),
#  ('Walter Gregor', 'AI'),
#  ('George Grey', 'AI'),
#  ('Henry Rowland Ellison Grey', 'AI'),
#  ('Lepel Griffin', 'AI'),
#  ('James Oliff Griffits', 'AI'),
#  ('William Vernon Guise', 'AI'),
#  ('James Guthrie', 'AI'),
#  ("Johann Franz ('Julius') Haast", 'AI'),
#  ('Alexander C Hamilton', 'AI'),
#  ('Archibald Hamilton', 'AI'),
#  ('Rowland Hamilton', 'AI'),
#  ('Richard Davis Hanson', 'AI'),
#  ('Clarence Harcourt', 'AI'),
#  ('William Harding', 'AI'),
#  ('Samuel Harraden', 'AI'),
#  ('Arthur B Harris', 'AI'),
#  ('James Penn Harris', 'AI'),
#  ('Charles (1) Harrison', 'AI'),
#  ('William Henry Harrison', 'AI'),
#  ('Alfred Edmund Harriss', 'AI'),
#  ('John E Harvey', 'AI'),
#  ('Frederick Augustus Haserick', 'AI'),
#  ('George Hawkins', 'AI'),
#  ('Ferdinand Vandeveer Hayden', 'AI'),
#  ('Edward Charles Healey', 'AI'),
#  ('Dunbar Isidore Heath', 'AI'),
#  ('G J D Heath', 'AI'),
#  ('Alexander Henderson', 'AI'),
#  ('David Mitchell Henderson', 'AI'),
#  ('P Henderson', 'AI'),
#  ('Joseph Henry', 'AI'),
#  ('Robert Hepburn', 'AI'),
#  ('John Mason Hepworth', 'AI'),
#  ('Matthew Heslop', 'AI'),
#  ('B Hewitt', 'AI'),
#  ('Alfred Hewlett', 'AI'),
#  ('James Heywood', 'AI'),
#  ('James Higgin', 'AI'),
#  ('Alfred Higgins', 'AI'),
#  ('R  Harvey Hilliard', 'AI'),
#  ('Frederick Hindmarsh', 'AI'),
#  ('W G E Hobbs', 'AI'),
#  ('Brian Houghton Hodgson', 'AI'),
#  ('Kirkman Daniel Hodgson', 'AI'),
#  ('Carl Alphonse Hoffman', 'AI'),
#  ('Joseph Hooker', 'AI'),
#  ('James Hope', 'AI'),
#  ('John Camden Hotten', 'AI'),
#  ('Frederick Hovenden', 'AI'),
#  ('W T Howard', 'AI'),
#  ('Henry Hoyle Howorth', 'AI'),
#  ('Henry Hudson', 'AI'),
#  ('Thomas McKenny Hughes', 'AI'),
#  ('John (2) Hunt', 'AI'),
#  ('William Wilson Hunter', 'AI'),
#  ('Jonathan Hutchinson', 'AI'),
#  ('Thomas Henry Huxley', 'AI'),
#  ('John Inglis', 'AI'),
#  ('x Isenburg', 'AI'),
#  ('Henry (the son) Jackson', 'AI'),
#  ('Henry William (1) Jackson', 'AI'),
#  ('J W Jackson', 'AI'),
#  ('Horatio Gay James', 'AI'),
#  ('John Moore Jeffcott', 'AI'),
#  ('Frederick John Jeffery', 'AI'),
#  ('Edmund Jeffries', 'AI'),
#  ('William Jennings', 'AI'),
#  ('Leonard Jenyns LATER Blomefield', 'AI'),
#  ('William Jepson', 'AI'),
#  ('George Curling Joad', 'AI'),
#  ('Arthur Johnson', 'AI'),
#  ('x Johore', 'AI'),
#  ('James Jones', 'AI'),
#  ('William Arthur Jones', 'AI'),
#  ('J W  (2) Kaye', 'AI'),
#  ('Claude Buchanan Ker', 'AI'),
#  ('Nicolai de Khanikof', 'AI'),
#  ('Joshua Edward Killick', 'AI'),
#  ('William Kincaid', 'AI'),
#  ('Edwin Holborow King', 'AI'),
#  ('Richard King', 'AI'),
#  ('Charles Kingsley', 'AI'),
#  ('David Kinloch', 'AI'),
#  ('Richard Kirwan', 'AI'),
#  ('J L Knapp', 'AI'),
#  ('William White La Barte', 'AI'),
#  ('Samuel Laing', 'AI'),
#  ('Thomas Josiah Laing', 'AI'),
#  ('John Lancaster', 'AI'),
#  ('Augustus Henry Lane Fox later Pitt Rivers', 'AI'),
#  ('Andrew Lang', 'AI'),
#  ('J Langlands', 'AI'),
#  ('Robert Gordon Latham', 'AI'),
#  ('Edward Lawford', 'AI'),
#  ('Austen Henry Layard', 'AI'),
#  ('John Edward Lee', 'AI'),
#  ('Samuel Lees', 'AI'),
#  ('Joseph Leidy', 'AI'),
#  ('Henry Leighton', 'AI'),
#  ('Arthur Charles Wriothesley Lennox', 'AI'),
#  ('Richard Lepsius', 'AI'),
#  ('Karl Georg Friedrich Rudolf Leuckart', 'AI'),
#  ('William Lockhart', 'AI'),
#  ('Abraham Logan', 'AI'),
#  ('J R Logan', 'AI'),
#  ('William Long', 'AI'),
#  ('Edward Lord', 'AI'),
#  ('Horatio Love', 'AI'),
#  ('Basil Lovery', 'AI'),
#  ('John Lubbock', 'AI'),
#  ('Johann Constantin August Lucae', 'AI'),
#  ('William Collings Lukis', 'AI'),
#  ('John Alfred Lush', 'AI'),
#  ('Coryndon H Luxmoore', 'AI'),
#  ('John Macartney', 'AI'),
#  ('John Gray Macfarlane', 'AI'),
#  ('G Macgowan', 'AI'),
#  ('Draper Mackinder', 'AI'),
#  ('David Mackintosh', 'AI'),
#  ('Hector Maclean', 'AI'),
#  ('George Macleay', 'AI'),
#  ('Andrew Maclure', 'AI'),
#  ('William Elphinstone Malcolm', 'AI'),
#  ('Robert James Mann', 'AI'),
#  ('Clements Robert Markham', 'AI'),
#  ('Matthew Henry Marsh', 'AI'),
#  ('Edward W Martin', 'AI'),
#  ('John (2) Martin', 'AI'),
#  ('Richard Biddulph Martin', 'AI'),
#  ('James Wood Mason', 'AI'),
#  ('James Mathieson', 'AI'),
#  ('Henry Matthews', 'AI'),
#  ('Alfred Maury', 'AI'),
#  ('Peter Benson Maxwell', 'AI'),
#  ('Edward Hooper May', 'AI'),
#  ('Joseph Mayer', 'AI'),
#  ('William Frederick Mayers', 'AI'),
#  ('John S Mayson', 'AI'),
#  ('James McClelland', 'AI'),
#  ('John McCormick', 'AI'),
#  ('John McDonnell', 'AI'),
#  ('John Ferguson McLennan', 'AI'),
#  ('Walter McLeod', 'AI'),
#  ('John Frederick McNair', 'AI'),
#  ('Barr Meadows', 'AI'),
#  ('Charles William Carter Madden Medlicott', 'AI'),
#  ('James Aitken Meigs', 'AI'),
#  ('John Magens Mello', 'AI'),
#  ('Evan Powell Meredith', 'AI'),
#  ('Alexander Michie', 'AI'),
#  ('William Augustus Miles', 'AI'),
#  ('John Miller', 'AI'),
#  ('Joseph Milligan', 'AI'),
#  ('Henry F Mills', 'AI'),
#  ('Henri Milne-Edwards', 'AI'),
#  ('x Milton', 'AI'),
#  ('Albert Mitchell', 'AI'),
#  ('Alexander (1) Mitchell', 'AI'),
#  ('Matthew Moggridge', 'AI'),
#  ('Frederick Butler Montgomerie', 'AI'),
#  ('John Moody', 'AI'),
#  ('George Moore', 'AI'),
#  ('Henry Reginald Moore', 'AI'),
#  ('John (1) Moore', 'AI'),
#  ('John (2) Moore', 'AI'),
#  ('Robert Waters Moore', 'AI'),
#  ('Fortescue John Morgan', 'AI'),
#  ('William Henry Morgan', 'AI'),
#  ('James Cotter Morison', 'AI'),
#  ('Edward Rowley Morris', 'AI'),
#  ('Eugene Morris', 'AI'),
#  ('John Morris', 'AI'),
#  ('James Holmes Morrison', 'AI'),
#  ('Walter Morrison', 'AI'),
#  ('John Mortimer', 'AI'),
#  ('John Robert Mortimer', 'AI'),
#  ('Henry Muirhead', 'AI'),
#  ('Friedrich Max Muller', 'AI'),
#  ('Francis Kerridge Munton', 'AI'),
#  ('J C Murray', 'AI'),
#  ('Charles Ottley Groom Napier', 'AI'),
#  ('William Napier', 'AI'),
#  ('Davyd William Nash', 'AI'),
#  ('Samuel Nash', 'AI'),
#  ('J  Dormer Neale', 'AI'),
#  ('Robert Stirling (1) Newall', 'AI'),
#  ('P H Newnham', 'AI'),
#  ('Alfred Vincent Newton', 'AI'),
#  ('Thomas Nicholas', 'AI'),
#  ('Brinsley Nicholson', 'AI'),
#  ('Charles Nicholson', 'AI'),
#  ('Giustiniano Nicolucci', 'AI'),
#  ('Sven Nilsson', 'AI'),
#  ('Karl Friedrich Nordmann', 'AI'),
#  ('Henry Norsworthy', 'AI'),
#  ('Samuel William North', 'AI'),
#  ('Josiah Clark Nott', 'AI'),
#  ('John Nottingham', 'AI'),
#  ('Richard Maddock Nunn', 'AI'),
#  ("P O'Callaghan", 'AI'),
#  ("Luke Smyth O'Connor", 'AI'),
#  ("Edward O'Riley", 'AI'),
#  ('Samuel Pasfield Oliver', 'AI'),
#  ('Gustav Oppert', 'AI'),
#  ('John Benn Ormathwaite', 'AI'),
#  ('W  Billing Orton', 'AI'),
#  ('Sherard Osborn', 'AI'),
#  ('John William Willoughby Osborne', 'AI'),
#  ('Charles Otto', 'AI'),
#  ('Frederick Ouvry', 'AI'),
#  ('John Fletcher Owen', 'AI'),
#  ('Richard Owen', 'AI'),
#  ('Robert Brisco Owen', 'AI'),
#  ('Samuel R J Owen', 'AI'),
#  ('William Gifford Palgrave', 'AI'),
#  ('Walter Mantell Parker', 'AI'),
#  ('J  Charlton Parr', 'AI'),
#  ("Theodore D'Orville Partridge", 'AI'),
#  ('Edmund Patterson', 'AI'),
#  ('R W Payne', 'AI'),
#  ('Thomas Bevill Peacock', 'AI'),
#  ('Alfred Henry Pechell', 'AI'),
#  ('Robert Peel', 'AI'),
#  ('John Peiser', 'AI'),
#  ('William Peppe', 'AI'),
#  ('Josef Anton Maximilian Perty', 'AI'),
#  ('Horace William Petherick', 'AI'),
#  ('Arthur Phayre', 'AI'),
#  ('Philip Phoebus', 'AI'),
#  ('Charles Pickering', 'AI'),
#  ('Francois Jules Pictet', 'AI'),
#  ('Bedford Pim', 'AI'),
#  ('John Platts', 'AI'),
#  ('Matthew Conway Poole', 'AI'),
#  ('Joseph Legg Postlethwaite', 'AI'),
#  ('Joseph Prestwich', 'AI'),
#  ('Frederick George Hilton Price', 'AI'),
#  ('Lorenzo T C Price', 'AI'),
#  ('Thomas Prichard', 'AI'),
#  ('Henry jun Prigg', 'AI'),
#  ('Alfred Pulford', 'AI'),
#  ('Arthur Giles Puller', 'AI'),
#  ('Bernard Quaritch', 'AI'),
#  ('Lambert Adolphe Jacques Quetelet', 'AI'),
#  ('James Rae', 'AI'),
#  ('A , jun Ramsay', 'AI'),
#  ('John Ramsay', 'AI'),
#  ('William Francis Ramsay', 'AI'),
#  ('Jabez Spence Ramskill', 'AI'),
#  ('Edwin Ransom', 'AI'),
#  ('Goday Naraen Gajapati Rao', 'AI'),
#  ('Charles Ratcliff', 'AI'),
#  ('Henry Rawlinson', 'AI'),
#  ('Lestock Robert Reid', 'AI'),
#  ('Ernest Renan', 'AI'),
#  ('Charles Jeremiah Renshaw', 'AI'),
#  ('Edward Jackson Riccard', 'AI'),
#  ('Franklin Thomas Richards', 'AI'),
#  ('Charles Richardson', 'AI'),
#  ('Francis Richardson', 'AI'),
#  ('George Thorne Ricketts', 'AI'),
#  ('x Ripon, De Grey and', 'AI'),
#  ('John Henry Rivett-Carnac', 'AI'),
#  ('Charles Robert des Ruffieres', 'AI'),
#  ('Daniel Brooke Robertson', 'AI'),
#  ('Edward Robinson', 'AI'),
#  ('William Robinson', 'AI'),
#  ('Sampson Roch', 'AI'),
#  ('George Rogers', 'AI'),
#  ('George Rolleston', 'AI'),
#  ('Hyacinthe Ronay', 'AI'),
#  ('Charles Rooke', 'AI'),
#  ('James Anderson Rose', 'AI'),
#  ('x Rosehill', 'AI'),
#  ('John George Clunies Ross', 'AI'),
#  ('Ankithum Venkata Nursing Row', 'AI'),
#  ('Harry Crommelin Rowcroft', 'AI'),
#  ('Frederick William Rudler', 'AI'),
#  ('H  Hodgson Rugg', 'AI'),
#  ('John Ruskin', 'AI'),
#  ('A H Russell', 'AI'),
#  ('Charles E Russell', 'AI'),
#  ('Edward Ryan', 'AI'),
#  ('Oluf Rygh', 'AI'),
#  ('David Salomons', 'AI'),
#  ('William Severin Salting', 'AI'),
#  ('Alfred Sanders', 'AI'),
#  ('W  Walbank Sanderson', 'AI'),
#  ('W H Scattergood', 'AI'),
#  ('William Mason Scharlieb', 'AI'),
#  ('Carl Ritter von Scherzer', 'AI'),
#  ('E Schiemann', 'AI'),
#  ('John (2) Scott', 'AI'),
#  ('Robert S Scott', 'AI'),
#  ('Thomas Scott', 'AI'),
#  ('John Scouler', 'AI'),
#  ('Lucy Ellen Sewall', 'AI'),
#  ('Peter Sharp', 'AI'),
#  ('Frederick George Shaw', 'AI'),
#  ('x Sheffield', 'AI'),
#  ('John Shortt', 'AI'),
#  ('Charles Lionel Showers', 'AI'),
#  ('Ramon de Silva-Ferro', 'AI'),
#  ('Frank Simpson', 'AI'),
#  ('James Simpson', 'AI'),
#  ('Frederick Mackenzie Skues', 'AI'),
#  ('William Mackenzie Skues', 'AI'),
#  ('Bath Charles Smart', 'AI'),
#  ('Andrew Smith', 'AI'),
#  ('John Smith', 'AI'),
#  ('Protheroe Smith', 'AI'),
#  ('Thomas Eustace Smith', 'AI'),
#  ('Thomas James Smith', 'AI'),
#  ('Worthington George Smith', 'AI'),
#  ('William Somervell', 'AI'),
#  ('Philip Southby', 'AI'),
#  ('Henry King Spark', 'AI'),
#  ('William Spottiswoode', 'AI'),
#  ('Ephraim George Squier', 'AI'),
#  ('George St Clair', 'AI'),
#  ('Spencer St John', 'AI'),
#  ('William Edward Stanbridge', 'AI'),
#  ('Japetus Steenstrup', 'AI'),
#  ('Carl (Karl) Steinhauer', 'AI'),
#  ('Charles Stenning', 'AI'),
#  ('William Frederick Cowell Stepney', 'AI'),
#  ('N  Henry Stevens', 'AI'),
#  ('Alexander Patrick Stewart', 'AI'),
#  ('Charles Edward Stewart', 'AI'),
#  ('John Stirling', 'AI'),
#  ('David Henry Stone', 'AI'),
#  ('William Story', 'AI'),
#  ('John Marmaduke Stourton', 'AI'),
#  ('James Strathern', 'AI'),
#  ('Andrew Struthers', 'AI'),
#  ('John William Studart', 'AI'),
#  ('Peter Cormac Sutherland', 'AI'),
#  ('Horace Swete', 'AI'),
#  ('Algernon Charles Swinburne', 'AI'),
#  ('Robert Swinhoe', 'AI'),
#  ('Francis Tagart', 'AI'),
#  ('Lawson Tait', 'AI'),
#  ('James Talbot de Malahide', 'AI'),
#  ('Richard Temple', 'AI'),
#  ('Edward Tenison Ryan Tenison', 'AI'),
#  ('John Tennant', 'AI'),
#  ('William, Jun Theobald', 'AI'),
#  ('Connop Thirlwall', 'AI'),
#  ('Frederick Thompson', 'AI'),
#  ('George C Thompson', 'AI'),
#  ('John Thomson', 'AI'),
#  ('L E Threlkeld', 'AI'),
#  ('Edward Thurlow', 'AI'),
#  ('John Thurnam', 'AI'),
#  ('Richard Hill Tiddeman', 'AI'),
#  ('Samuel Timmins', 'AI'),
#  ('John Tolhurst', 'AI'),
#  ('Albert Tootal', 'AI'),
#  ('Arthur Trevelyan', 'AI'),
#  ('Nicolas Trubner', 'AI'),
#  ('Charles jun Tuckett', 'AI'),
#  ('Thomas Harrington Tuke', 'AI'),
#  ('John Underwood', 'AI'),
#  ('Jonas Daniel Vaughan', 'AI'),
#  ('William Sandys Wright Vaux', 'AI'),
#  ('George Venables Vernon', 'AI'),
#  ('Carl Vogt', 'AI'),
#  ('Thomas Francis Wade', 'AI'),
#  ('Cornelius Walford', 'AI'),
#  ('Charles Pyndar Beauchamp Walker', 'AI'),
#  ('James Sydney Walker', 'AI'),
#  ('Thomas Walker', 'AI'),
#  ('Alfred Russel Wallace', 'AI'),
#  ('Joshua Walmsley', 'AI'),
#  ('Phillipp Alexander Walther', 'AI'),
#  ('Ottiwell Charles Waterfield', 'AI'),
#  ('Samuel Watson', 'AI'),
#  ('Robert Watt', 'AI'),
#  ('Hermann Welcker', 'AI'),
#  ('Hodder Michael Westropp', 'AI'),
#  ('James Whishaw', 'AI'),
#  ('x Wienecke', 'AI'),
#  ('John Gardner Wilkinson', 'AI'),
#  ('John (1) Williams', 'AI'),
#  ('John Wilkins Williams', 'AI'),
#  ('Daniel Wilson', 'AI'),
#  ('Frank Wilson', 'AI'),
#  ('Alfred Wiltshire', 'AI'),
#  ('William Smith Windham', 'AI'),
#  ('Henry Hoyte Winwood', 'AI'),
#  ('Thomas Alexander Wise', 'AI'),
#  ('James Wodderspoon', 'AI'),
#  ('Francis George Cornelius Wolber', 'AI'),
#  ('Samuel Wood', 'AI'),
#  ('William Spicer Wood', 'AI'),
#  ('Robert Carr Woods', 'AI'),
#  ('Francis Beresford Wright', 'AI'),
#  ('Thomas Wright', 'AI'),
#  ('Robert Younge', 'AI'),
#  ('Arthur de Zeltner', 'AI')]

# %%
print(len(node_names))
print(len(edges))
# Out:
# 610
# 610

# %%
print("First 5 nodes:", node_names[0:5])
print("First 5 edges:", edges[0:5])
# Out:
# First 5 nodes: ['H R Adam', 'William (2) Adams', 'Louis Agassiz', 'Alexander Muirhead Aitken', 'William Amhurst Tyssen Amhurst']
# First 5 edges: [('H R Adam', 'AI'), ('William (2) Adams', 'AI'), ('Louis Agassiz', 'AI'), ('Alexander Muirhead Aitken', 'AI'), ('William Amhurst Tyssen Amhurst', 'AI')]

# %%
G = nx.Graph()
G.add_nodes_from(node_names)
G.add_edges_from(edges)
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 611
# Number of edges: 610
# Average degree:   1.9967

# %%
# Nodes

birth_year_dict = {}
death_year_dict = {}
first_year_dict = {}
last_year_dict = {}
religion_id_dict = {}

# %%
for node in nodes: # Loop through the list, one row at a time
    
    birth_year_dict [node[0]] = node[1]
    death_year_dict [node[0]] = node[2]
    first_year_dict[node[0]] = node[3]
    last_year_dict[node[0]] = node[4]
    religion_id_dict[node[0]] = node[5]

# %%
# Nodes
nx.set_node_attributes(G, birth_year_dict, 'birth_year')
nx.set_node_attributes(G, death_year_dict, 'death_year')
nx.set_node_attributes(G, first_year_dict, 'first_year')
nx.set_node_attributes(G, last_year_dict, 'last_year')
nx.set_node_attributes(G, religion_id_dict, 'religion_id')

# %%
for n in G.nodes(): # Loop through every node, in our data "n" will be the name of the person
    print(n, G.nodes[n]['first_year']) # Access every node by its name, and then by the attribute "birth_year"
# Out:
# H R Adam 1870
# William (2) Adams 1858
# Louis Agassiz 1860
# Alexander Muirhead Aitken 1864
# William Amhurst Tyssen Amhurst 1862
# x Antrim 1871
# William Appleyard 1854
# William Arbuthnot 1868
# William Armitage 1864
# William Armstrong 1865
# Richard Arnold 1866
# William Arthur 1865
# Charles Frederick Ash 1864
# William Henry Ashurst 1863
# Charles Atkins 1868
# George Atkinson 1869
# Charles Cardale Babington 1864
# Edward Backhouse 1870
# Carl Ernst von Baer 1861
# Walter ('Badgett') Bagehot 1865
# James Bain 1865
# John Baker 1861
# Samuel C Baker 1866
# William Bailey Baker 1858
# George Balfour 1865
# John  Wheeldon Barnes 1870
# William Roby Barr 1863
# Thomas Squire Barrett 1865
# George William Barrington 1865
# William Edward Bartlett 1864
# John Stothert Bartrum 1865
# William Battye 1867
# Hermann Beigel 1865
# William Abraham Bell 1869
# Edward Bellamy 1865
# Henry Walter Bellew 1870
# Thomas Bendyshe 1863
# Charles Bennett 1867
# George Bertram 1864
# John Bilderbeck 1866
# James Bischoff 1865
# Andrew Black 1870
# William Blackmore 1866
# Henry Jules Blanc 1866
# Henry George Bohn 1861
# William Bollaert 1862
# Louis Lucien Bonaparte 1862
# George Bonavia 1870
# James Bonsor 1869
# James Bonwick 1869
# Cunningham Borthwick 1865
# Sydney Edward Bouverie Bouverie-Pusey 1863
# Jacob Boys 1863
# Edward William Brabrook 1864
# Frederick Braby 1865
# Charles Holt Bracebridge 1844
# Antonio Brady 1864
# P A Brady 1867
# William Bragge 1870
# A C Brebner 1867
# James Brebner 1863
# Charles Brett 1865
# John Briggs 1845
# Lindsay Brine 1869
# Charles Cornish Brown 1871
# James Roberts Brown 1864
# John Allen Brown 1865
# Thomas Henry Browne 1867
# George Bryant 1867
# William Bull 1867
# Luke Burke 1861
# George Busk 1863
# William John Busteed 1867
# Henry Butler 1864
# James Butler 1867
# Benjamin Bond Cabbell 1864
# John Calman 1870
# Archibald Campbell 1866
# Francis Campbell 1866
# George (1) Campbell 1869
# James Campbell 1864
# T A Campbell 1868
# Walter Campbell 1870
# William Camps 1845
# Charles Napoleon de Cardi 1868
# William D Carey 1865
# John Burford Carlill 1867
# Samuel Cartwright 1863
# George Catlin 1866
# John Cavafy 1865
# John Henry Challis 1865
# William Chamberlin 1863
# Charles Harcourt Chambers 1863
# William Chambers 1864
# Frank Chance 1863
# Edward Charlesworth 1866
# William Charlton 1865
# William Dinsdale Child 1844
# Samuel Chinnery 1865
# William Nathan Chipperfield 1865
# T J Cholmondeley 1868
# Hyde Clarke 1864
# Robert Clarke 1862
# William Aloysius Clavering 1861
# John (1) Cleghorn 1869
# H Clerk 1864
# John Colam 1870
# Henry Cole 1864
# Vicat Cole 1865
# John Sherrard Coleman 1854
# John Frederick Collingwood 1863
# W W Collins 1862
# John (1) Collinson 1866
# Moncure Daniel Conway 1869
# William Fothergill Cooke 1864
# Daniel Cooper 1863
# Frederick Cooper 1866
# William C Copperthwaite 1867
# Tullie Cornthwaite 1846
# Frederick William Cosens 1864
# Samuel Courtauld 1864
# Henry Augustus Cowper 1866
# Tom junr Craston 1868
# Oswald John Crawfurd 1861
# Henry Crowley 1864
# Moore A Cuffe 1870
# Richard Cull 1845
# Richard S Cunliffe 1855
# Alexander Cunningham 1869
# Edward Barrett Hodges Curteis 1867
# John Richmond Cuthbert 1863
# George Cutler 1860
# William Barrington D'Almeida 1867
# x Daa 1866
# G  Wythes Daniell 1858
# Robert Dukinfield Darbishire 1869
# George Russell Dartnell 1867
# Charles Darwin 1861
# Arthur Dashwood 1868
# John Davidson 1867
# Jesse Conway Davies 1866
# William Davies 1869
# George Henry Daw 1868
# William Boyd Dawkins 1869
# George Dawson 1863
# x Derby (formerly Stanley) 1864
# x Devonshire 1862
# George Dibley 1864
# Charles Wentworth Dilke 1870
# John Dingle 1863
# Jacob Ludwig Dohne 1856
# John Langdon H Down 1865
# D I Drakeford 1866
# John Drummond 1864
# Alexander Duncan 1868
# David Duncan 1870
# Francis Duncan 1867
# Peter Martin Duncan 1869
# Alfred John Dunkin 1868
# Robert Dunn 1845
# William Eassie 1864
# Joseph William Eastwood 1862
# Casper W Eddy 1868
# John Edwards 1870
# Walter Elliot 1869
# C H  Fairfax Ellis 1867
# William Erle 1863
# Edward Bickerton Evans 1864
# John Evans 1863
# Edward John Eyre 1864
# William Fairbairn 1867
# Adam Storey Farrar 1870
# Frederick Fearon 1864
# Edwin Foxton Firby 1864
# Frederick Firebrace 1864
# James Firm 1854
# Robert Fischer 1866
# Morton Coates Fisher 1870
# George Fleming 1863
# John Wickham Flower 1869
# George Folsom 1866
# David Forbes 1868
# Robert Nicholas Fowler 1851
# Charles Henry Fox 1861
# William Henry Francklyne 1869
# Augustus Wollaston Franks 1863
# Thomas Fraser 1865
# William Freund 1853
# Danby Palmer Fry 1863
# A  de Fullner 1866
# Albert Fytche 1866
# Douglas Galton 1861
# Francis Galton 1862
# C T Gardner 1869
# Charles Henry Gardner 1864
# E V Gardner 1861
# Peter Gardner 1846
# John Peter Gassiot 1862
# George Duncan Gibb 1863
# Enrico Hillyer Giglioli 1862
# William Gillespie 1865
# Spyridon Glaucopides 1863
# Augustus Goldsmid 1865
# Richard Thomas Gore 1860
# James Gowans 1866
# Ryves William Graves 1867
# Frederick King Green 1869
# George Courthope Green 1867
# William Greenwell 1868
# William Rathbone Greg 1865
# Walter Gregor 1863
# George Grey 1860
# Henry Rowland Ellison Grey 1861
# Lepel Griffin 1866
# James Oliff Griffits 1866
# William Vernon Guise 1869
# James Guthrie 1862
# Johann Franz ('Julius') Haast 1870
# Alexander C Hamilton 1869
# Archibald Hamilton 1863
# Rowland Hamilton 1853
# Richard Davis Hanson 1870
# Clarence Harcourt 1864
# William Harding 1865
# Samuel Harraden 1865
# Arthur B Harris 1866
# James Penn Harris 1867
# Charles (1) Harrison 1869
# William Henry Harrison 1868
# Alfred Edmund Harriss 1869
# John E Harvey 1863
# Frederick Augustus Haserick 1866
# George Hawkins 1864
# Ferdinand Vandeveer Hayden 1869
# Edward Charles Healey 1864
# Dunbar Isidore Heath 1864
# G J D Heath 1869
# Alexander Henderson 1854
# David Mitchell Henderson 1870
# P Henderson 1870
# Joseph Henry 1869
# Robert Hepburn 1855
# John Mason Hepworth 1863
# Matthew Heslop 1870
# B Hewitt 1871
# Alfred Hewlett 1863
# James Heywood 1844
# James Higgin 1863
# Alfred Higgins 1863
# R  Harvey Hilliard 1870
# Frederick Hindmarsh 1845
# W G E Hobbs 1864
# Brian Houghton Hodgson 1863
# Kirkman Daniel Hodgson 1863
# Carl Alphonse Hoffman 1870
# Joseph Hooker 1868
# James Hope 1870
# John Camden Hotten 1867
# Frederick Hovenden 1868
# W T Howard 1865
# Henry Hoyle Howorth 1856
# Henry Hudson 1864
# Thomas McKenny Hughes 1869
# John (2) Hunt 1866
# William Wilson Hunter 1870
# Jonathan Hutchinson 1863
# Thomas Henry Huxley 1863
# John Inglis 1854
# x Isenburg 1854
# Henry (the son) Jackson 1863
# Henry William (1) Jackson 1863
# J W Jackson 1863
# Horatio Gay James 1865
# John Moore Jeffcott 1869
# Frederick John Jeffery 1869
# Edmund Jeffries 1864
# William Jennings 1864
# Leonard Jenyns LATER Blomefield 1863
# William Jepson 1867
# George Curling Joad 1865
# Arthur Johnson 1869
# x Johore 1866
# James Jones 1862
# William Arthur Jones 1869
# J W  (2) Kaye 1868
# Claude Buchanan Ker 1867
# Nicolai de Khanikof 1866
# Joshua Edward Killick 1864
# William Kincaid 1865
# Edwin Holborow King 1869
# Richard King 1866
# Charles Kingsley 1856
# David Kinloch 1870
# Richard Kirwan 1869
# J L Knapp 1854
# William White La Barte 1863
# Samuel Laing 1864
# Thomas Josiah Laing 1867
# John Lancaster 1863
# Augustus Henry Lane Fox later Pitt Rivers 1865
# Andrew Lang 1861
# J Langlands 1867
# Robert Gordon Latham 1844
# Edward Lawford 1867
# Austen Henry Layard 1853
# John Edward Lee 1870
# Samuel Lees 1863
# Joseph Leidy 1869
# Henry Leighton 1867
# Arthur Charles Wriothesley Lennox 1866
# Richard Lepsius 1854
# Karl Georg Friedrich Rudolf Leuckart 1861
# William Lockhart 1861
# Abraham Logan 1863
# J R Logan 1866
# William Long 1869
# Edward Lord 1863
# Horatio Love 1850
# Basil Lovery 1868
# John Lubbock 1863
# Johann Constantin August Lucae 1861
# William Collings Lukis 1864
# John Alfred Lush 1869
# Coryndon H Luxmoore 1864
# John Macartney 1869
# John Gray Macfarlane 1865
# G Macgowan 1861
# Draper Mackinder 1863
# David Mackintosh 1867
# Hector Maclean 1867
# George Macleay 1869
# Andrew Maclure 1867
# William Elphinstone Malcolm 1855
# Robert James Mann 1866
# Clements Robert Markham 1864
# Matthew Henry Marsh 1862
# Edward W Martin 1869
# John (2) Martin 1864
# Richard Biddulph Martin 1868
# James Wood Mason 1869
# James Mathieson 1863
# Henry Matthews 1863
# Alfred Maury 1861
# Peter Benson Maxwell 1867
# Edward Hooper May 1867
# Joseph Mayer 1854
# William Frederick Mayers 1864
# John S Mayson 1856
# James McClelland 1854
# John McCormick 1868
# John McDonnell 1864
# John Ferguson McLennan 1870
# Walter McLeod 1863
# John Frederick McNair 1866
# Barr Meadows 1867
# Charles William Carter Madden Medlicott 1867
# James Aitken Meigs 1861
# John Magens Mello 1867
# Evan Powell Meredith 1867
# Alexander Michie 1863
# William Augustus Miles 1851
# John Miller 1867
# Joseph Milligan 1863
# Henry F Mills 1866
# Henri Milne-Edwards 1863
# x Milton 1864
# Albert Mitchell 1868
# Alexander (1) Mitchell 1858
# Matthew Moggridge 1869
# Frederick Butler Montgomerie 1864
# John Moody 1868
# George Moore 1864
# Henry Reginald Moore 1865
# John (1) Moore 1864
# John (2) Moore 1866
# Robert Waters Moore 1866
# Fortescue John Morgan 1863
# William Henry Morgan 1866
# James Cotter Morison 1863
# Edward Rowley Morris 1871
# Eugene Morris 1869
# John Morris 1869
# James Holmes Morrison 1869
# Walter Morrison 1870
# John Mortimer 1864
# John Robert Mortimer 1870
# Henry Muirhead 1867
# Friedrich Max Muller 1865
# Francis Kerridge Munton 1870
# J C Murray 1867
# Charles Ottley Groom Napier 1865
# William Napier 1868
# Davyd William Nash 1848
# Samuel Nash 1870
# J  Dormer Neale 1868
# Robert Stirling (1) Newall 1870
# P H Newnham 1863
# Alfred Vincent Newton 1865
# Thomas Nicholas 1869
# Brinsley Nicholson 1855
# Charles Nicholson 1858
# Giustiniano Nicolucci 1862
# Sven Nilsson 1860
# Karl Friedrich Nordmann 1868
# Henry Norsworthy 1867
# Samuel William North 1863
# Josiah Clark Nott 1861
# John Nottingham 1867
# Richard Maddock Nunn 1865
# P O'Callaghan 1870
# Luke Smyth O'Connor 1864
# Edward O'Riley 1860
# Samuel Pasfield Oliver 1868
# Gustav Oppert 1869
# John Benn Ormathwaite 1864
# W  Billing Orton 1868
# Sherard Osborn 1867
# John William Willoughby Osborne 1864
# Charles Otto 1853
# Frederick Ouvry 1869
# John Fletcher Owen 1868
# Richard Owen 1863
# Robert Brisco Owen 1863
# Samuel R J Owen 1864
# William Gifford Palgrave 1868
# Walter Mantell Parker 1870
# J  Charlton Parr 1868
# Theodore D'Orville Partridge 1867
# Edmund Patterson 1860
# R W Payne 1866
# Thomas Bevill Peacock 1863
# Alfred Henry Pechell 1866
# Robert Peel 1866
# John Peiser 1863
# William Peppe 1869
# Josef Anton Maximilian Perty 1860
# Horace William Petherick 1863
# Arthur Phayre 1862
# Philip Phoebus 1861
# Charles Pickering 1861
# Francois Jules Pictet 1860
# Bedford Pim 1866
# John Platts 1869
# Matthew Conway Poole 1871
# Joseph Legg Postlethwaite 1844
# Joseph Prestwich 1869
# Frederick George Hilton Price 1868
# Lorenzo T C Price 1868
# Thomas Prichard 1865
# Henry jun Prigg 1863
# Alfred Pulford 1866
# Arthur Giles Puller 1865
# Bernard Quaritch 1865
# Lambert Adolphe Jacques Quetelet 1853
# James Rae 1864
# A , jun Ramsay 1863
# John Ramsay 1867
# William Francis Ramsay 1867
# Jabez Spence Ramskill 1865
# Edwin Ransom 1868
# Goday Naraen Gajapati Rao 1866
# Charles Ratcliff 1863
# Henry Rawlinson 1853
# Lestock Robert Reid 1861
# Ernest Renan 1861
# Charles Jeremiah Renshaw 1863
# Edward Jackson Riccard 1867
# Franklin Thomas Richards 1867
# Charles Richardson 1864
# Francis Richardson 1863
# George Thorne Ricketts 1870
# x Ripon, De Grey and 1850
# John Henry Rivett-Carnac 1870
# Charles Robert des Ruffieres 1863
# Daniel Brooke Robertson 1864
# Edward Robinson 1852
# William Robinson 1865
# Sampson Roch 1865
# George Rogers 1867
# George Rolleston 1860
# Hyacinthe Ronay 1865
# Charles Rooke 1866
# James Anderson Rose 1868
# x Rosehill 1870
# John George Clunies Ross 1860
# Ankithum Venkata Nursing Row 1870
# Harry Crommelin Rowcroft 1861
# Frederick William Rudler 1871
# H  Hodgson Rugg 1867
# John Ruskin 1864
# A H Russell 1860
# Charles E Russell 1868
# Edward Ryan 1862
# Oluf Rygh 1866
# David Salomons 1860
# William Severin Salting 1863
# Alfred Sanders 1864
# W  Walbank Sanderson 1869
# W H Scattergood 1866
# William Mason Scharlieb 1867
# Carl Ritter von Scherzer 1861
# E Schiemann 1870
# John (2) Scott 1867
# Robert S Scott 1863
# Thomas Scott 1866
# John Scouler 1855
# Lucy Ellen Sewall 1868
# Peter Sharp 1864
# Frederick George Shaw 1866
# x Sheffield 1865
# John Shortt 1863
# Charles Lionel Showers 1862
# Ramon de Silva-Ferro 1863
# Frank Simpson 1865
# James Simpson 1869
# Frederick Mackenzie Skues 1866
# William Mackenzie Skues 1863
# Bath Charles Smart 1861
# Andrew Smith 1864
# John Smith 1863
# Protheroe Smith 1863
# Thomas Eustace Smith 1867
# Thomas James Smith 1869
# Worthington George Smith 1865
# William Somervell 1862
# Philip Southby 1867
# Henry King Spark 1864
# William Spottiswoode 1861
# Ephraim George Squier 1852
# George St Clair 1863
# Spencer St John 1863
# William Edward Stanbridge 1863
# Japetus Steenstrup 1863
# Carl (Karl) Steinhauer 1863
# Charles Stenning 1863
# William Frederick Cowell Stepney 1867
# N  Henry Stevens 1862
# Alexander Patrick Stewart 1855
# Charles Edward Stewart 1869
# John Stirling 1866
# David Henry Stone 1864
# William Story 1865
# John Marmaduke Stourton 1867
# James Strathern 1868
# Andrew Struthers 1868
# John William Studart 1865
# Peter Cormac Sutherland 1871
# Horace Swete 1869
# Algernon Charles Swinburne 1865
# Robert Swinhoe 1861
# Francis Tagart 1871
# Lawson Tait 1868
# James Talbot de Malahide 1860
# Richard Temple 1865
# Edward Tenison Ryan Tenison 1863
# John Tennant 1863
# William, Jun Theobald 1866
# Connop Thirlwall 1864
# Frederick Thompson 1864
# George C Thompson 1866
# John Thomson 1866
# L E Threlkeld 1854
# Edward Thurlow 1863
# John Thurnam 1852
# Richard Hill Tiddeman 1870
# Samuel Timmins 1865
# John Tolhurst 1867
# Albert Tootal 1867
# Arthur Trevelyan 1863
# Nicolas Trubner 1863
# Charles jun Tuckett 1864
# Thomas Harrington Tuke 1849
# John Underwood 1860
# Jonas Daniel Vaughan 1865
# William Sandys Wright Vaux 1871
# George Venables Vernon 1863
# Carl Vogt 1863
# Thomas Francis Wade 1865
# Cornelius Walford 1866
# Charles Pyndar Beauchamp Walker 1865
# James Sydney Walker 1854
# Thomas Walker 1854
# Alfred Russel Wallace 1866
# Joshua Walmsley 1867
# Phillipp Alexander Walther 1862
# Ottiwell Charles Waterfield 1864
# Samuel Watson 1863
# Robert Watt 1869
# Hermann Welcker 1862
# Hodder Michael Westropp 1863
# James Whishaw 1846
# x Wienecke 1862
# John Gardner Wilkinson 1853
# John (1) Williams 1867
# John Wilkins Williams 1867
# Daniel Wilson 1863
# Frank Wilson 1866
# Alfred Wiltshire 1868
# William Smith Windham 1866
# Henry Hoyte Winwood 1869
# Thomas Alexander Wise 1866
# James Wodderspoon 1869
# Francis George Cornelius Wolber 1868
# Samuel Wood 1860
# William Spicer Wood 1863
# Robert Carr Woods 1863
# Francis Beresford Wright 1870
# Thomas Wright 1853
# Robert Younge 1865
# Arthur de Zeltner 1865
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-ffade7d34fce> in <module>
#       1 for n in G.nodes(): # Loop through every node, in our data "n" will be the name of the person
# ----> 2     print(n, G.nodes[n]['first_year']) # Access every node by its name, and then by the attribute "birth_year"
#
# KeyError: 'first_year'

# %%
#nx.write_gexf(G, 'jnb_hddt_ceda_ai.gexf')
